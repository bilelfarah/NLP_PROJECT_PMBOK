# %%
def convert_pdf_to_img(pdf_file):

    return convert_from_path(pdf_file)


def convert_image_to_text(file):

    
    text = image_to_string(file)
    return text


def get_text_from_any_pdf(pdf_file):

    images = convert_pdf_to_img(pdf_file)
    final_text = ""
    for pg, img in enumerate(images):
        
        final_text += convert_image_to_text(img)
        #print("Page n°{}".format(pg))
        #print(convert_image_to_text(img))
    
    return final_text

# %%
path_to_pdf = 'CostSansFigure.pdf'

# %%
textextract = get_text_from_any_pdf(path_to_pdf)
print(textextract)
# Out:
# PROJECT COST MANAGEMENT
#
# Project Cost Management includes the processes involved in planning, estimating, budgeting, financing, funding,
# managing, and controlling costs so that the project can be completed within the approved budget. The Project Cost
# Management processes are:
#
# 7.1 Plan Cost Management—The process of defining how the project costs will be estimated, budgeted, managed,
# monitored, and controlled.
#
# 7.2 Estimate Costs—The process of developing an approximation of the monetary resources needed to complete
# project work.
#
# 7.3 Determine Budget—The process of aggregating the estimated costs of individual activities or work packages to
# establish an authorized cost baseline.
#
# 7.4 Control Costs—The process of monitoring the status of the project to update the project costs and manage
# changes to the cost baseline.
#
# Figure 7-1 provides an overview of the Project Cost Management processes. The Project Cost Management processes
# ...

# %%
textextract=textextract.replace("@","")
textextract=textextract.replace("¢","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
#textextract=textextract.replace(".","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
textextract=textextract.replace("-","")
textextract=textextract.replace("Part 1  Guide","")
textextract=textextract.replace("'","")
#textextract=textextract.replace("71","souschapitre1")
#textextract=textextract.replace("72","souschapitre2")
#textextract=textextract.replace("73","souschapitre3")
#textextract=textextract.replace("74","souschapitre4")

textextract = textextract.replace('; 7A', '')
textextract = textextract.replace('eecccccccccsccsccccccoe >', '')
textextract = textextract.replace('\nm', '')
textextract = textextract.replace('SS', '')
textextract = textextract.replace('XR J', '')
textextract = textextract.replace('« ', '')
textextract = textextract.replace('m=>', '')
textextract = textextract.replace('= ', '')
textextract = textextract.replace('wy', '')
textextract = textextract.replace('ececcececencccccccccccececceseeg|', '')
textextract = textextract.replace('| seeerceecccccsccccccscn de Documents', '')
textextract = textextract.replace('=e', '')
textextract = textextract.replace('ez', '')
textextract = textextract.replace('———>', '')
textextract = textextract.replace('\no', '')
with open('CostSansFigure.txt', 'w', encoding="utf-8") as fp:
    fp.write(textextract)

# %%
textextract
# Out:
# 'PROJECT COST MANAGEMENT\n\nProject Cost Management includes the processes involved in planning, estimating, budgeting, financing, funding,anaging, and controlling costs so that the project can be completed within the approved budget. The Project Cost\nManagement processes are:\n\n7.1 Plan Cost Management—The process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled.\n\n7.2 Estimate Costs—The process of developing an approximation of the monetary resources needed to complete\nproject work.\n\n7.3 Determine Budget—The process of aggregating the estimated costs of individual activities or work packages to\nestablish an authorized cost baseline.\n\n7.4 Control Costs—The process of monitoring the status of the project to update the project costs and manage\nchanges to the cost baseline.\n\nFigure 71 provides an overview of the Project Cost Management processes. The Project Cost Management processes\nare presented as discrete processes with de
# ...

# %%
Titre = re.findall(r"[0-9].*[A-Z]\n",textextract)
Titre.sort()
Titre
# Out:
# ['4.3.2.2. Project management information systems are often used to monitor the three EVM\n',
#  '7.1 PLAN COST MANAGEMENT\n',
#  '7.1.1 PLAN COST MANAGEMENT: INPUTS\n',
#  '7.1.1.1. PROJECT CHARTER\n',
#  '7.1.1.2 PROJECT MANAGEMENT PLAN\n',
#  '7.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '7.1.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '7.1.2 PLAN COST MANAGEMENT: TOOLS AND TECHNIQUES\n',
#  '7.1.2.1 EXPERT JUDGMENT\n',
#  '7.1.2.2 DATA ANALYSIS\n',
#  '7.1.2.3 MEETINGS\n',
#  '7.1.3 PLAN COST MANAGEMENT: OUTPUTS\n',
#  '7.1.3.1. COST MANAGEMENT PLAN\n',
#  '7.2 ESTIMATE COSTS\n',
#  '7.2.1 ESTIMATE COSTS: INPUTS\n',
#  '7.2.1.1 PROJECT MANAGEMENT PLAN\n',
#  '7.2.1.2 PROJECT DOCUMENTS\n',
#  '7.2.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '7.2.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '7.2.2 ESTIMATE COSTS: TOOLS AND TECHNIQUES\n',
#  '7.2.2.1 EXPERT JUDGMENT\n',
#  '7.2.2.2 ANALOGOUS ESTIMATING\n',
#  '7.2.2.3 PARAMETRIC ESTIMATING\n',
#  '7.2.2.4 BOTTOMUP ESTIMATING\n',
# ...

# %%
import pandas as pd
dict = {'Concept': Titre} 
df405 = pd.DataFrame(dict)
df405
# Out:
#                                               Concept
# 0   4.3.2.2. Project management information system...
# 1                          7.1 PLAN COST MANAGEMENT\n
# 2                7.1.1 PLAN COST MANAGEMENT: INPUTS\n
# 3                          7.1.1.1. PROJECT CHARTER\n
# 4                   7.1.1.2 PROJECT MANAGEMENT PLAN\n
# ..                                                ...
# 62             7.4.3.1 WORK PERFORMANCE INFORMATION\n
# 63                           7.4.3.2 COST FORECASTS\n
# 64                          7.4.3.3 CHANGE REQUESTS\n
# 65          7.4.3.4 PROJECT MANAGEMENT PLAN UPDATES\n
# 66                7.4.3.5 PROJECT DOCUMENTS UPDATES\n
#
# [67 rows x 1 columns]

# %%
df405.drop(df405.head(1).index,inplace=True)

# %%
Content = re.findall(r'[0-9][^\S\n]+[A-Z]+[\S\n+](?:[^\S\n]+[A-Z]+)*(?:\n(?!7\.\[0-9].[0-9].[0-9].[0-9]).*)+', textextract)
print(Content)
# Out:
# ['1 PLAN COST MANAGEMENT\n\nPlan Cost Management is the process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled. The key benefit of this process is that it provides guidance and direction on how the project\ncosts will be managed throughout the project. This process is performed once or at predefined points in the project. The\ninputs, tools and techniques, and outputs of this process are depicted in Figure 72. Figure 73 depicts the data flow\ndiagram of the process.\n\n235\nThe cost management planning effort occurs early in project planning and sets the framework for each of the costanagement processes so that performance of the processes will be efficient and coordinated. The cost management\nprocesses and their associated tools and techniques are documented in the cost management plan. The cost management\nplan is a component of the project management plan.\n\n7.1.1 PLAN COST MANAGEMENT: INPUTS\n\n7.1.1.1. PROJECT CHARTER\n\nDescrib
# ...

# %%
a = []
for i in Content:
    if i not in a:
        a.append(i)
Content= a
print(Content)
# Out:
# ['1 PLAN COST MANAGEMENT\n\nPlan Cost Management is the process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled. The key benefit of this process is that it provides guidance and direction on how the project\ncosts will be managed throughout the project. This process is performed once or at predefined points in the project. The\ninputs, tools and techniques, and outputs of this process are depicted in Figure 72. Figure 73 depicts the data flow\ndiagram of the process.\n\n235\nThe cost management planning effort occurs early in project planning and sets the framework for each of the costanagement processes so that performance of the processes will be efficient and coordinated. The cost management\nprocesses and their associated tools and techniques are documented in the cost management plan. The cost management\nplan is a component of the project management plan.\n\n7.1.1 PLAN COST MANAGEMENT: INPUTS\n\n7.1.1.1. PROJECT CHARTER\n\nDescrib
# ...

# %%
Content = list(map(lambda x: x.replace('|', 'PIPE'), Content))

# %%
Content = list(map(lambda x: x.replace('7.1.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.1.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.1.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.1.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.2.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.2.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.2.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.2.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.3.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.3.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.3.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.3.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.4.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.4.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('7.4.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('\n', ''), Content))

Content
# Out:
# ['1 PLAN COST MANAGEMENTPlan Cost Management is the process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled. The key benefit of this process is that it provides guidance and direction on how the projectcosts will be managed throughout the project. This process is performed once or at predefined points in the project. Theinputs, tools and techniques, and outputs of this process are depicted in Figure 72. Figure 73 depicts the data flowdiagram of the process.235The cost management planning effort occurs early in project planning and sets the framework for each of the costanagement processes so that performance of the processes will be efficient and coordinated. The cost managementprocesses and their associated tools and techniques are documented in the cost management plan. The cost managementplan is a component of the project management plan.7.1.1 PLAN COST MANAGEMENT: INPUTS | 1. PROJECT CHARTERDescribed in Section 4.2.3.1. The project 
# ...

# %%
mystring=""
for x in Content:
    mystring += x
mystring = mystring.replace('\n', ' ').replace('\r', '')
mystring
# Out:
# '1 PLAN COST MANAGEMENTPlan Cost Management is the process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled. The key benefit of this process is that it provides guidance and direction on how the projectcosts will be managed throughout the project. This process is performed once or at predefined points in the project. Theinputs, tools and techniques, and outputs of this process are depicted in Figure 72. Figure 73 depicts the data flowdiagram of the process.235The cost management planning effort occurs early in project planning and sets the framework for each of the costanagement processes so that performance of the processes will be efficient and coordinated. The cost managementprocesses and their associated tools and techniques are documented in the cost management plan. The cost managementplan is a component of the project management plan.7.1.1 PLAN COST MANAGEMENT: INPUTS | 1. PROJECT CHARTERDescribed in Section 4.2.3.1. The project c
# ...

# %%
one = mystring.split('|');
one
# Out:
# ['1 PLAN COST MANAGEMENTPlan Cost Management is the process of defining how the project costs will be estimated, budgeted, managed,onitored, and controlled. The key benefit of this process is that it provides guidance and direction on how the projectcosts will be managed throughout the project. This process is performed once or at predefined points in the project. Theinputs, tools and techniques, and outputs of this process are depicted in Figure 72. Figure 73 depicts the data flowdiagram of the process.235The cost management planning effort occurs early in project planning and sets the framework for each of the costanagement processes so that performance of the processes will be efficient and coordinated. The cost managementprocesses and their associated tools and techniques are documented in the cost management plan. The cost managementplan is a component of the project management plan.7.1.1 PLAN COST MANAGEMENT: INPUTS ',
# ...

# %%
import pandas as pd
df13 = pd.DataFrame(one)   
df13=df13.rename(columns = {0:'Content'})
df13
# Out:
#                                               Content
# 0   1 PLAN COST MANAGEMENTPlan Cost Management is ...
# 1    1. PROJECT CHARTERDescribed in Section 4.2.3....
# 2    2 PROJECT MANAGEMENT PLANDescribed in Section...
# 3    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...
# 4    4 ORGANIZATIONAL PROCE AETSThe organizational...
# ..                                                ...
# 62   4 PROJECT MANAGEMENT PLAN UPDATESAny change t...
# 63   1. Changes to the cost management plan, such ...
# 64   1. Changes to the cost baseline are incorpora...
# 65   5 PROJECT DOCUMENTS UPDATESProject documents ...
# 66   1. Cost estimates may need to be updated to r...
#
# [67 rows x 1 columns]

# %%
df1000=df405.join(df13)
df1000
# Out:
#                                        Concept  \
# 1                   7.1 PLAN COST MANAGEMENT\n
# 2         7.1.1 PLAN COST MANAGEMENT: INPUTS\n
# 3                   7.1.1.1. PROJECT CHARTER\n
# 4            7.1.1.2 PROJECT MANAGEMENT PLAN\n
# 5   7.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# ..                                         ...
# 62      7.4.3.1 WORK PERFORMANCE INFORMATION\n
# 63                    7.4.3.2 COST FORECASTS\n
# 64                   7.4.3.3 CHANGE REQUESTS\n
# 65   7.4.3.4 PROJECT MANAGEMENT PLAN UPDATES\n
# 66         7.4.3.5 PROJECT DOCUMENTS UPDATES\n
#
#                                               Content
# 1    1. PROJECT CHARTERDescribed in Section 4.2.3....
# 2    2 PROJECT MANAGEMENT PLANDescribed in Section...
# 3    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...
# 4    4 ORGANIZATIONAL PROCE AETSThe organizational...
# 5    1 EXPERT JUDGMENTDescribed in Section 4.1.2.1...
# ..                                                ...
# ...

# %%
for i in range(1,66):
    if ((df1000.loc[i,['Concept']].str.contains('INPUTS')).bool()):
        df1000.loc[i,['TYPE']]='INPUTS'
    elif ((df1000.loc[i,['Concept']].str.contains('TOOLS AND TECHNIQUES')).bool()):
        df1000.loc[i,['TYPE']]='Tools and Techniques'
    elif ((df1000.loc[i,['Concept']].str.contains('OUTPUTS')).bool()):
        df1000.loc[i,['TYPE']]='Outputs'
df1000.head(51)
# Out:
#                                               Concept  \
# 1                          7.1 PLAN COST MANAGEMENT\n
# 2                7.1.1 PLAN COST MANAGEMENT: INPUTS\n
# 3                          7.1.1.1. PROJECT CHARTER\n
# 4                   7.1.1.2 PROJECT MANAGEMENT PLAN\n
# 5          7.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 6                 7.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 7   7.1.2 PLAN COST MANAGEMENT: TOOLS AND TECHNIQU...
# 8                           7.1.2.1 EXPERT JUDGMENT\n
# 9                             7.1.2.2 DATA ANALYSIS\n
# 10                                 7.1.2.3 MEETINGS\n
# 11              7.1.3 PLAN COST MANAGEMENT: OUTPUTS\n
# 12                    7.1.3.1. COST MANAGEMENT PLAN\n
# 13                               7.2 ESTIMATE COSTS\n
# 14                     7.2.1 ESTIMATE COSTS: INPUTS\n
# 15                  7.2.1.1 PROJECT MANAGEMENT PLAN\n
# 16                        7.2.1.2 PROJECT DOCUMENTS\n
# ...

# %%
df1000['Definition'] = df1000['Content']
df1000=df1000.replace({'Definition':'Described in Section [0-9].*'},{'Definition':''} , regex=True)
df1000=df1000.replace({'Definition':'depicted in Section [0-9].*'},{'Definition':''} , regex=True)
df1000.head(50)
# Out:
#                                               Concept  \
# 1                          7.1 PLAN COST MANAGEMENT\n
# 2                7.1.1 PLAN COST MANAGEMENT: INPUTS\n
# 3                          7.1.1.1. PROJECT CHARTER\n
# 4                   7.1.1.2 PROJECT MANAGEMENT PLAN\n
# 5          7.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 6                 7.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 7   7.1.2 PLAN COST MANAGEMENT: TOOLS AND TECHNIQU...
# 8                           7.1.2.1 EXPERT JUDGMENT\n
# 9                             7.1.2.2 DATA ANALYSIS\n
# 10                                 7.1.2.3 MEETINGS\n
# 11              7.1.3 PLAN COST MANAGEMENT: OUTPUTS\n
# 12                    7.1.3.1. COST MANAGEMENT PLAN\n
# 13                               7.2 ESTIMATE COSTS\n
# 14                     7.2.1 ESTIMATE COSTS: INPUTS\n
# 15                  7.2.1.1 PROJECT MANAGEMENT PLAN\n
# 16                        7.2.1.2 PROJECT DOCUMENTS\n
# ...

# %%
df1000['REF']=df1000['Content'].str.findall(r'Described in Section \d.\d.\d.\d+')
df1000['REF']=df1000['REF']+df1000['Content'].str.findall(r'depicted in Figure \d+')
df1000['REF']=df1000['REF']+df1000['Content'].str.findall(r'Figure \d\d+')

# %%
df1000['REF'][23]
# Out:
# ['Described in Section 4.1.3.2',
#  'Described in Section 4.4.3.1',
#  'depicted in Figure 76',
#  'Figure 76',
#  'Figure 77']

# %%
df1000['Content'][23]
# Out:
# ' 3 PROJECT DOCUMENTS UPDATESProject documents that may be updated as a result of carrying out this process include but are not limited to: Assumption log. Described in Section 4.1.3.2. During the Cost Estimates process, new assumptions may beade, new constraints may be identified, and existing assumptions or constraints may be revisited and changed.The assumption log should be updated with this new information. Lessons learned register. Described in Section 4.4.3.1. The lessons learned register can be updated withtechniques that were efficient and effective in developing cost estimates. Risk register. Described in Section 11.2.3.1. The risk register may be updated when appropriate risk responsesare chosen and agreed upon during the Estimate Cost process.7.3 DETERMINE BUDGETDetermine Budget is the process of aggregating the estimated costs of individual activities or work packages toestablish an authorized cost baseline. The key benefit of this process is that it determines the cost 
# ...

# %%
df1000['Definition'][23]
# Out:
# ' 3 PROJECT DOCUMENTS UPDATESProject documents that may be updated as a result of carrying out this process include but are not limited to: Assumption log. '

# %%
def remove_retourLigne(text):
    return re.sub("\n","",text)

# %%
from collections import Counter
def remove_irr_char_func(text):
    '''
    Removes all irrelevant characters (numbers and punctuation) from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without irrelevant characters
    '''
    return re.sub(r'[^a-zA-Z]', ' ', text)

# %%
def unique_list(text_str):
    l = text_str.split()
    temp = []
    for x in l:
        if x not in temp:
            temp.append(x)
    return ' '.join(temp)

# %%
def wordlowercase(text):
    return text.lower ()

# %%
def remove_punctuation_func(text):
    '''
    Removes all punctuation from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without punctuations
    '''
    return re.sub(r'[^a-zA-Z0-9]', ' ', text)

# %%
def remove_white_spaces(text):
    return re.sub(' +', ' ', text)

# %%
def remove_extra_whitespaces_func(text):
    '''
    Removes extra whitespaces from a string, if present
    
    Args:
        text (str): String to which the function is to be applied, string
    
    Returns:
        Clean string without extra whitespaces
    ''' 
    return re.sub(r'^\s*|\s\s*', ' ', text).strip()

# %%
def remove_non_ascii(text):
    """
        Remove non-ASCII characters 
    """
    return re.sub(r'[^\x00-\x7f]',r'', text)

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : remove_retourLigne(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12052/320420947.py in <module>
# ----> 1 df1000['Content'] = df1000['Content'].apply(lambda x : remove_retourLigne(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : remove_irr_char_func(x))

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : unique_list(x))

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : wordlowercase(x))

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : remove_punctuation_func(x))

# %%
df1000['Content'] = df1000['Content'].apply(lambda x : remove_extra_whitespaces_func(x))

# %%
kv,nzdnvlzvelvvl,v

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import span
from spacy import displacy


import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer,SnowballStemmer
from nltk.corpus import wordnet, stopwords
from nltk import pos_tag, RegexpParser

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')

# %%
from nltk.corpus import wordnet as wn
def lemmatize_text (text):
    lemmatizer = WordNetLemmatizer()
    return lemmatizer.lemmatize(text)
def synonym (text):
    words = text.split()
    words = [lemmatize_text(i) for i in words]
    synonym = []
    for word in words:
        for syn in wn.synsets(word):
            for l in syn.lemmas():
                synonym.append(l.name())
    return set(synonym)

# %%
df20['synonym'] = df20['Content'].apply(lambda x: synonym(x))

# %%
df20

# %%
df20.to_csv('CostTEST.csv', sep=' ', encoding='utf-8', header='true')
