# %%
# Useful libraries
from pdf2image import convert_from_path
from pytesseract import image_to_string
from PIL import Image
import csv 
import re

# %%
def convert_pdf_to_img(pdf_file):

    return convert_from_path(pdf_file)


def convert_image_to_text(file):

    
    text = image_to_string(file)
    return text


def get_text_from_any_pdf(pdf_file):

    images = convert_pdf_to_img(pdf_file)
    final_text = ""
    for pg, img in enumerate(images):
        
        final_text += convert_image_to_text(img)
        #print("Page n°{}".format(pg))
        #print(convert_image_to_text(img))
    
    return final_text

# %%
path_to_pdf = 'Schedule.pdf'

# %%
textextract = get_text_from_any_pdf(path_to_pdf)
print(textextract)
# Out:
# PROJECT SCHEDULE MANAGEMENT
#
# Project Schedule Management includes the processes required to manage the timely completion of the project.
# The Project Schedule Management processes are:
#
# 6.1 Plan Schedule Management—The process of establishing the policies, procedures, and documentation for
# planning, developing, managing, executing, and controlling the project schedule.
#
# 6.2 Define Activities—The process of identifying and documenting the specific actions to be performed to produce
# the project deliverables.
#
# 6.3 Sequence Activities—The process of identifying and documenting relationships among the project activities.
#
# 6.4 Estimate Activity Durations—tThe process of estimating the number of work periods needed to complete
# individual activities with the estimated resources.
#
# 6.5 Develop Schedule—The process of analyzing activity sequences, durations, resource requirements, and
# ...

# %%
import re
Figure = re.findall(r"Figure\s[6]-[0-9]{1,2}.\s[A-Z]{1}.*", textextract)
Figure.sort()
Figure
# Out:
# ['Figure 6-1. Project Schedule Management Overview',
#  'Figure 6-10. Examples of Lead and Lag',
#  'Figure 6-10. Lag can also be represented in project',
#  'Figure 6-10. Lead is often',
#  'Figure 6-11. Project Schedule Network Diagram',
#  'Figure 6-12. Estimate Activity Durations: Inputs, Tools & Techniques, and Outputs',
#  'Figure 6-12. Figure 6-13 depicts the data flow diagram of the process.',
#  'Figure 6-13. Estimate Activity Durations: Data Flow Diagram',
#  'Figure 6-14. Develop Schedule: Inputs, Tools & Techniques, and Outputs',
#  'Figure 6-14. Figure 6-15 depicts the data flow diagram of the process.',
#  'Figure 6-15. Develop Schedule: Data Flow Diagram',
#  'Figure 6-16. Example of Critical Path Method',
#  'Figure 6-16. In this',
#  'Figure 6-17. Resource Leveling',
#  'Figure 6-18. Example Probability Distribution of a Target Milestone',
#  'Figure 6-19. Schedule Compression Comparison',
#  'Figure 6-2. Scheduling Overview',
# ...

# %%
import pandas as pd
dict = {'Figure': Figure}
df22 = pd.DataFrame(dict)
df22
# Out:
#                                                Figure
# 0    Figure 6-1. Project Schedule Management Overview
# 1               Figure 6-10. Examples of Lead and Lag
# 2   Figure 6-10. Lag can also be represented in pr...
# 3                          Figure 6-10. Lead is often
# 4       Figure 6-11. Project Schedule Network Diagram
# 5   Figure 6-12. Estimate Activity Durations: Inpu...
# 6   Figure 6-12. Figure 6-13 depicts the data flow...
# 7   Figure 6-13. Estimate Activity Durations: Data...
# 8   Figure 6-14. Develop Schedule: Inputs, Tools &...
# 9   Figure 6-14. Figure 6-15 depicts the data flow...
# 10   Figure 6-15. Develop Schedule: Data Flow Diagram
# 11       Figure 6-16. Example of Critical Path Method
# 12                               Figure 6-16. In this
# 13                     Figure 6-17. Resource Leveling
# 14  Figure 6-18. Example Probability Distribution ...
# 15       Figure 6-19. Schedule Compression Comparison
# ...

# %%
path_to_pdf = 'ScheduleSansFigure.pdf'

# %%
textextract = get_text_from_any_pdf(path_to_pdf)
print(textextract)
# Out:
# PROJECT SCHEDULE MANAGEMENT
# Project Schedule Management includes the processes required to manage the timely completion of the project.
# The Project Schedule Management processes are:
#
# 6.1 Plan Schedule Management—The process of establishing the policies, procedures, and documentation for
# planning, developing, managing, executing, and controlling the project schedule.
#
# 6.2 Define Activities—The process of identifying and documenting the specific actions to be performed to produce
# the project deliverables.
#
# 6.3 Sequence Activities—The process of identifying and documenting relationships among the project activities.
#
# 6.4 Estimate Activity Durations—The process of estimating the number of work periods needed to complete
# individual activities with the estimated resources.
#
# 6.5 Develop Schedule—The process of analyzing activity sequences, durations, resource requirements, and
# ...

# %%
textextract=textextract.replace("@","")
textextract=textextract.replace("¢","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
#textextract=textextract.replace(".","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
textextract=textextract.replace("-","")
textextract=textextract.replace("Part 1  Guide","")
textextract=textextract.replace("'","")
#textextract=textextract.replace("71","souschapitre1")
#textextract=textextract.replace("72","souschapitre2")
#textextract=textextract.replace("73","souschapitre3")
#textextract=textextract.replace("74","souschapitre4")

textextract = textextract.replace('; 7A', '')
textextract = textextract.replace('eecccccccccsccsccccccoe >', '')
textextract = textextract.replace('\nm', '')
textextract = textextract.replace('SS', '')
textextract = textextract.replace('XR J', '')
textextract = textextract.replace('« ', '')
textextract = textextract.replace('m=>', '')
textextract = textextract.replace('= ', '')
textextract = textextract.replace('wy', '')
textextract = textextract.replace('ececcececencccccccccccececceseeg|', '')
textextract = textextract.replace('| seeerceecccccsccccccscn de Documents', '')
textextract = textextract.replace('=e', '')
textextract = textextract.replace('ez', '')
textextract = textextract.replace('———>', '')
textextract = textextract.replace('\no', '')
with open('ScheduleSansFigure.txt', 'w', encoding="utf-8") as fp:
    fp.write(textextract)

# %%
textextract
# Out:
# 'PROJECT SCHEDULE MANAGEMENT\nProject Schedule Management includes the processes required to manage the timely completion of the project.\nThe Project Schedule Management processes are:\n\n6.1 Plan Schedule Management—The process of establishing the policies, procedures, and documentation for\nplanning, developing, managing, executing, and controlling the project schedule.\n\n6.2 Define Activities—The process of identifying and documenting the specific actions to be performed to produce\nthe project deliverables.\n\n6.3 Sequence Activities—The process of identifying and documenting relationships among the project activities.\n\n6.4 Estimate Activity Durations—The process of estimating the number of work periods needed to complete\nindividual activities with the estimated resources.\n\n6.5 Develop Schedule—The process of analyzing activity sequences, durations, resource requirements, and\nschedule constraints to create the project schedule model for project execution and monitoring an
# ...

# %%
SousTitre = re.findall(r"[6].[0-9].[0-9].[0-9].*[A-Z]\n", textextract)
SousTitre.sort()
SousTitre
# Out:
# ['6.1.1.1 PROJECT CHARTER\n',
#  '6.1.1.2 PROJECT MANAGEMENT PLAN\n',
#  '6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '6.1.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '6.1.2.1 EXPERT JUDGMENT\n',
#  '6.1.2.2 DATA ANALYSIS\n',
#  '6.1.2.3 MEETINGS\n',
#  '6.1.3.1 SCHEDULE MANAGEMENT PLAN\n',
#  '6.2.1.1 PROJECT MANAGEMENT PLAN\n',
#  '6.2.1.2 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '6.2.1.3 ORGANIZATIONAL PROCE AETS\n',
#  '6.2.2.1 EXPERT JUDGMENT\n',
#  '6.2.2.2 DECOMPOSITION\n',
#  '6.2.2.3 ROLLING WAVE PLANNING\n',
#  '6.2.2.4 MEETINGS\n',
#  '6.2.3.1 ACTIVITY LIST\n',
#  '6.2.3.2 ACTIVITY ATTRIBUTES\n',
#  '6.2.3.3 MILESTONE LIST\n',
#  '6.2.3.4 CHANGE REQUESTS\n',
#  '6.2.3.5 PROJECT MANAGEMENT PLAN UPDATES\n',
#  '6.3.1.1 PROJECT MANAGEMENT PLAN\n',
#  '6.3.1.2 PROJECT DOCUMENTS\n',
#  '6.3.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '6.3.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '6.3.2.1 PRECEDENCE DIAGRAMMING METHOD\n',
#  '6.3.2.2 DEPENDENCY DETERMINATION AND INTEGRATION\n',
# ...

# %%
import pandas as pd
dict = {'SousTitre': SousTitre}
df = pd.DataFrame(dict)
df
# Out:
#                                      SousTitre
# 0                    6.1.1.1 PROJECT CHARTER\n
# 1            6.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2   6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3          6.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4                    6.1.2.1 EXPERT JUDGMENT\n
# ..                                         ...
# 72      6.6.3.1 WORK PERFORMANCE INFORMATION\n
# 73                6.6.3.2 SCHEDULE FORECASTS\n
# 74                   6.6.3.3 CHANGE REQUESTS\n
# 75   6.6.3.4 PROJECT MANAGEMENT PLAN UPDATES\n
# 76         6.6.3.5 PROJECT DOCUMENTS UPDATES\n
#
# [77 rows x 1 columns]

# %%
numSousTitre=[]
numSousTitre = re.findall(r"[6].[0-9].[0-9].[0-9] ", textextract)
numSousTitre
# Out:
# ['6.1.1.1 ',
#  '6.1.1.2 ',
#  '6.1.1.3 ',
#  '6.1.1.4 ',
#  '6.1.2.1 ',
#  '6.1.2.2 ',
#  '6.1.2.3 ',
#  '6.1.3.1 ',
#  '6.2.1.1 ',
#  '6.2.1.2 ',
#  '6.2.1.3 ',
#  '6.2.2.1 ',
#  '6.2.2.2 ',
#  '6.2.2.3 ',
#  '6.2.2.4 ',
#  '6.2.3.1 ',
#  '6.2.3.2 ',
#  '6.2.3.3 ',
#  '6.2.3.4 ',
#  '6.2.3.5 ',
#  '6.3.1.1 ',
#  '6.3.1.2 ',
#  '6.3.1.3 ',
#  '6.3.1.4 ',
#  '6.3.2.1 ',
#  '6.3.2.2 ',
#  '6.3.2.3 ',
#  '6.3.2.4 ',
#  '6.3.3.1 ',
#  '6.3.3.2 ',
#  '6.4.1.1 ',
#  '6.4.1.2 ',
#  '6.4.1.3 ',
#  '6.4.1.4 ',
#  '6.4.2.1 ',
#  '6.4.2.2 ',
#  '6.4.2.3 ',
#  '6.4.2.4 ',
#  '6.4.2.5 ',
#  '6.4.2.6 ',
#  '6.4.2.7 ',
#  '6.4.2.8 ',
#  '6.4.3.1 ',
#  '6.4.3.2 ',
#  '6.4.3.3 ',
#  '6.5.1.1 ',
#  '6.5.1.2 ',
#  '6.5.1.3 ',
#  '6.5.1.4 ',
#  '6.5.1.5 ',
#  '6.5.2.1 ',
#  '6.5.2.2 ',
#  '6.5.2.3 ',
#  '6.5.2.4 ',
#  '6.5.2.5 ',
#  '6.5.2.6 ',
#  '6.5.2.7 ',
#  '6.5.2.8 ',
#  '6.5.3.1 ',
#  '6.5.3.2 ',
#  '6.5.3.3 ',
#  '6.5.3.4 ',
#  '6.5.3.5 ',
#  '6.5.3.6 ',
#  '6.5.3.7 ',
#  '6.6.1.1 ',
# ...

# %%
import pandas as pd
dict = {'numSousTitre': numSousTitre} 
df4 = pd.DataFrame(dict)
df4.shape
# Out:
# (80, 1)

# %%
df09=df4.join(df)
df5=df09.join(df22)
df5
# Out:
#    numSousTitre                                   SousTitre  \
# 0      6.1.1.1                    6.1.1.1 PROJECT CHARTER\n
# 1      6.1.1.2            6.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2      6.1.1.3   6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3      6.1.1.4          6.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4      6.1.2.1                    6.1.2.1 EXPERT JUDGMENT\n
# ..          ...                                         ...
# 75     6.6.3.1    6.6.3.4 PROJECT MANAGEMENT PLAN UPDATES\n
# 76     6.6.3.2          6.6.3.5 PROJECT DOCUMENTS UPDATES\n
# 77     6.6.3.3                                          NaN
# 78     6.6.3.4                                          NaN
# 79     6.6.3.5                                          NaN
#
#                                                Figure
# 0    Figure 6-1. Project Schedule Management Overview
# 1               Figure 6-10. Examples of Lead and Lag
# 2   Figure 6-10. Lag can also be represented in pr...
# ...

# %%
Chapitre = re.findall(r"[6].[0-9] .*[A-Z]", textextract)
Chapitre.sort()
Chapitre
# Out:
# ['6.1 CONTROL SCHEDULE: INPUTS',
#  '6.1 PLAN SCHEDULE MANAGEMENT',
#  '6.1 Plan Schedule Management—T',
#  '6.2 CONTROL SCHEDULE: TOOLS AND TECHNIQUES',
#  '6.2 DEFINE ACTIVITIES',
#  '6.2 Define Activities—T',
#  '6.3 CONTROL SCHEDULE: OUTPUTS',
#  '6.3 SEQUENCE ACTIVITIES',
#  '6.3 Sequence Activities—T',
#  '6.4 ESTIMATE ACTIVITY DURATIONS',
#  '6.4 Estimate Activity Durations—T',
#  '6.5 DEVELOP SCHEDULE',
#  '6.5 Develop Schedule—T',
#  '6.6 CONTROL SCHEDULE',
#  '6.6 Control Schedule—T',
#  '611 illustrates a project schedule network diagram. A',
#  '611 in the relationship between activities H']

# %%
dict = {'Chapitre': Chapitre} 
df17 = pd.DataFrame(dict)
df17
# Out:
#                                              Chapitre
# 0                        6.1 CONTROL SCHEDULE: INPUTS
# 1                        6.1 PLAN SCHEDULE MANAGEMENT
# 2                      6.1 Plan Schedule Management—T
# 3          6.2 CONTROL SCHEDULE: TOOLS AND TECHNIQUES
# 4                               6.2 DEFINE ACTIVITIES
# 5                             6.2 Define Activities—T
# 6                       6.3 CONTROL SCHEDULE: OUTPUTS
# 7                             6.3 SEQUENCE ACTIVITIES
# 8                           6.3 Sequence Activities—T
# 9                     6.4 ESTIMATE ACTIVITY DURATIONS
# 10                  6.4 Estimate Activity Durations—T
# 11                               6.5 DEVELOP SCHEDULE
# 12                             6.5 Develop Schedule—T
# 13                               6.6 CONTROL SCHEDULE
# 14                             6.6 Control Schedule—T
# 15  611 illustrates a project schedule network dia...
# ...

# %%
numChapitre = re.findall(r"[6].[0-9] ",textextract)
numChapitre.sort()
numChapitre
# Out:
# ['6.1 ',
#  '6.1 ',
#  '6.1 ',
#  '6.2 ',
#  '6.2 ',
#  '6.2 ',
#  '6.3 ',
#  '6.3 ',
#  '6.3 ',
#  '6.4 ',
#  '6.4 ',
#  '6.5 ',
#  '6.5 ',
#  '6.6 ',
#  '6.6 ',
#  '611 ',
#  '611 ',
#  '613 ',
#  '615 ',
#  '618 ',
#  '619 ',
#  '620 ',
#  '621 ',
#  '621 ',
#  '621 ',
#  '623 ',
#  '624 ']

# %%
dict = {'numChapitre': numChapitre} 
df16 = pd.DataFrame(dict)
df16
# Out:
#    numChapitre
# 0         6.1
# 1         6.1
# 2         6.1
# 3         6.2
# 4         6.2
# 5         6.2
# 6         6.3
# 7         6.3
# 8         6.3
# 9         6.4
# 10        6.4
# 11        6.5
# 12        6.5
# 13        6.6
# 14        6.6
# 15        611
# 16        611
# 17        613
# 18        615
# 19        618
# 20        619
# 21        620
# 22        621
# 23        621
# 24        621
# 25        623
# 26        624

# %%
df15= df16.join(df17)
df15
# Out:
#    numChapitre                                           Chapitre
# 0         6.1                        6.1 CONTROL SCHEDULE: INPUTS
# 1         6.1                        6.1 PLAN SCHEDULE MANAGEMENT
# 2         6.1                      6.1 Plan Schedule Management—T
# 3         6.2          6.2 CONTROL SCHEDULE: TOOLS AND TECHNIQUES
# 4         6.2                               6.2 DEFINE ACTIVITIES
# 5         6.2                             6.2 Define Activities—T
# 6         6.3                       6.3 CONTROL SCHEDULE: OUTPUTS
# 7         6.3                             6.3 SEQUENCE ACTIVITIES
# 8         6.3                           6.3 Sequence Activities—T
# 9         6.4                     6.4 ESTIMATE ACTIVITY DURATIONS
# 10        6.4                   6.4 Estimate Activity Durations—T
# 11        6.5                                6.5 DEVELOP SCHEDULE
# 12        6.5                              6.5 Develop Schedule—T
# ...

# %%
SousChapitre = re.findall(r"[6].[0-9].[0-9] .*[A-Z]\n", textextract)
SousChapitre.sort()
SousChapitre
# Out:
# ['6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS\n',
#  '6.1.1 PROJECT MANAGEMENT PLAN\n',
#  '6.1.2 PLAN SCHEDULE MANAGEMENT: TOOLS AND TECHNIQUES\n',
#  '6.1.2 PROJECT DOCUMENTS\n',
#  '6.1.3 PLAN SCHEDULE MANAGEMENT: OUTPUTS\n',
#  '6.1.3 WORK PERFORMANCE DATA\n',
#  '6.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '6.2.1 DATA ANALYSIS\n',
#  '6.2.1 DEFINE ACTIVITIES: INPUTS\n',
#  '6.2.2 CRITICAL PATH METHOD\n',
#  '6.2.2 DEFINE ACTIVITIES: TOOLS AND TECHNIQUES\n',
#  '6.2.3 DEFINE ACTIVITIES: OUTPUTS\n',
#  '6.2.4 RESOURCE OPTIMIZATION\n',
#  '6.2.5 LEADS AND LAGS\n',
#  '6.2.6 SCHEDULE COMPREION\n',
#  '6.3.1 SEQUENCE ACTIVITIES: INPUTS\n',
#  '6.3.1 WORK PERFORMANCE INFORMATION\n',
#  '6.3.2 SCHEDULE FORECASTS\n',
#  '6.3.2 SEQUENCE ACTIVITIES: TOOLS AND TECHNIQUES\n',
#  '6.3.3 CHANGE REQUESTS\n',
#  '6.3.3 SEQUENCE ACTIVITIES: OUTPUTS\n',
#  '6.3.4 PROJECT MANAGEMENT PLAN UPDATES\n',
#  '6.3.5 PROJECT DOCUMENTS UPDATES\n',
#  '6.4.1 ESTIMATE ACTIVITY DURATIONS: INPUTS\n',
# ...

# %%
import pandas as pd
dict = {'SousChapitre': SousChapitre} 
df1 = pd.DataFrame(dict)
df1
# Out:
#                                          SousChapitre
# 0            6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS\n
# 1                     6.1.1 PROJECT MANAGEMENT PLAN\n
# 2   6.1.2 PLAN SCHEDULE MANAGEMENT: TOOLS AND TECH...
# 3                           6.1.2 PROJECT DOCUMENTS\n
# 4           6.1.3 PLAN SCHEDULE MANAGEMENT: OUTPUTS\n
# 5                       6.1.3 WORK PERFORMANCE DATA\n
# 6                   6.1.4 ORGANIZATIONAL PROCE AETS\n
# 7                               6.2.1 DATA ANALYSIS\n
# 8                   6.2.1 DEFINE ACTIVITIES: INPUTS\n
# 9                        6.2.2 CRITICAL PATH METHOD\n
# 10    6.2.2 DEFINE ACTIVITIES: TOOLS AND TECHNIQUES\n
# 11                 6.2.3 DEFINE ACTIVITIES: OUTPUTS\n
# 12                      6.2.4 RESOURCE OPTIMIZATION\n
# 13                             6.2.5 LEADS AND LAGS\n
# 14                         6.2.6 SCHEDULE COMPREION\n
# 15                6.3.1 SEQUENCE ACTIVITIES: INPUTS\n
# ...

# %%
numSousChapitre = re.findall(r"[6].[0-9].[0-9] ", textextract)
numSousChapitre.sort()
numSousChapitre
# Out:
# ['6.1.1 ',
#  '6.1.1 ',
#  '6.1.2 ',
#  '6.1.2 ',
#  '6.1.3 ',
#  '6.1.3 ',
#  '6.1.4 ',
#  '6.2.1 ',
#  '6.2.1 ',
#  '6.2.2 ',
#  '6.2.2 ',
#  '6.2.3 ',
#  '6.2.3 ',
#  '6.2.4 ',
#  '6.2.5 ',
#  '6.2.6 ',
#  '6.3.1 ',
#  '6.3.1 ',
#  '6.3.2 ',
#  '6.3.2 ',
#  '6.3.3 ',
#  '6.3.3 ',
#  '6.3.4 ',
#  '6.3.5 ',
#  '6.4.1 ',
#  '6.4.2 ',
#  '6.4.3 ',
#  '6.5.1 ',
#  '6.5.2 ',
#  '6.5.3 ',
#  '6.6.1 ',
#  '6.6.2 ',
#  '6.6.3 ']

# %%
dict = {'numSousChapitre': numSousChapitre} 
df11 = pd.DataFrame(dict)
df11
# Out:
#    numSousChapitre
# 0           6.1.1
# 1           6.1.1
# 2           6.1.2
# 3           6.1.2
# 4           6.1.3
# 5           6.1.3
# 6           6.1.4
# 7           6.2.1
# 8           6.2.1
# 9           6.2.2
# 10          6.2.2
# 11          6.2.3
# 12          6.2.3
# 13          6.2.4
# 14          6.2.5
# 15          6.2.6
# 16          6.3.1
# 17          6.3.1
# 18          6.3.2
# 19          6.3.2
# 20          6.3.3
# 21          6.3.3
# 22          6.3.4
# 23          6.3.5
# 24          6.4.1
# 25          6.4.2
# 26          6.4.3
# 27          6.5.1
# 28          6.5.2
# 29          6.5.3
# 30          6.6.1
# 31          6.6.2
# 32          6.6.3

# %%
df23=df11.join(df1)
df23
# Out:
#    numSousChapitre                                       SousChapitre
# 0           6.1.1            6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS\n
# 1           6.1.1                     6.1.1 PROJECT MANAGEMENT PLAN\n
# 2           6.1.2   6.1.2 PLAN SCHEDULE MANAGEMENT: TOOLS AND TECH...
# 3           6.1.2                           6.1.2 PROJECT DOCUMENTS\n
# 4           6.1.3           6.1.3 PLAN SCHEDULE MANAGEMENT: OUTPUTS\n
# 5           6.1.3                       6.1.3 WORK PERFORMANCE DATA\n
# 6           6.1.4                   6.1.4 ORGANIZATIONAL PROCE AETS\n
# 7           6.2.1                               6.2.1 DATA ANALYSIS\n
# 8           6.2.1                   6.2.1 DEFINE ACTIVITIES: INPUTS\n
# 9           6.2.2                        6.2.2 CRITICAL PATH METHOD\n
# 10          6.2.2     6.2.2 DEFINE ACTIVITIES: TOOLS AND TECHNIQUES\n
# 11          6.2.3                  6.2.3 DEFINE ACTIVITIES: OUTPUTS\n
# ...

# %%
df3=df23.join(df15)
df3
# Out:
#    numSousChapitre                                       SousChapitre  \
# 0           6.1.1            6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS\n
# 1           6.1.1                     6.1.1 PROJECT MANAGEMENT PLAN\n
# 2           6.1.2   6.1.2 PLAN SCHEDULE MANAGEMENT: TOOLS AND TECH...
# 3           6.1.2                           6.1.2 PROJECT DOCUMENTS\n
# 4           6.1.3           6.1.3 PLAN SCHEDULE MANAGEMENT: OUTPUTS\n
# 5           6.1.3                       6.1.3 WORK PERFORMANCE DATA\n
# 6           6.1.4                   6.1.4 ORGANIZATIONAL PROCE AETS\n
# 7           6.2.1                               6.2.1 DATA ANALYSIS\n
# 8           6.2.1                   6.2.1 DEFINE ACTIVITIES: INPUTS\n
# 9           6.2.2                        6.2.2 CRITICAL PATH METHOD\n
# 10          6.2.2     6.2.2 DEFINE ACTIVITIES: TOOLS AND TECHNIQUES\n
# 11          6.2.3                  6.2.3 DEFINE ACTIVITIES: OUTPUTS\n
# ...

# %%
df18=df5.join(df3)
df18
# Out:
#    numSousTitre                                   SousTitre  \
# 0      6.1.1.1                    6.1.1.1 PROJECT CHARTER\n
# 1      6.1.1.2            6.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2      6.1.1.3   6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3      6.1.1.4          6.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4      6.1.2.1                    6.1.2.1 EXPERT JUDGMENT\n
# ..          ...                                         ...
# 75     6.6.3.1    6.6.3.4 PROJECT MANAGEMENT PLAN UPDATES\n
# 76     6.6.3.2          6.6.3.5 PROJECT DOCUMENTS UPDATES\n
# 77     6.6.3.3                                          NaN
# 78     6.6.3.4                                          NaN
# 79     6.6.3.5                                          NaN
#
#                                                Figure numSousChapitre  \
# 0    Figure 6-1. Project Schedule Management Overview          6.1.1
# 1               Figure 6-10. Examples of Lead and Lag          6.1.1
# ...

# %%
Content = re.findall(r'[0-9].[0-9].[0-9].[0-9][^\S\n]+[A-Z]+[\S\n+](?:[^\S\n]+[A-Z]+)*(?:\n(?!7\.\[0-9].[0-9].[0-9].[0-9]).*)+', textextract)
print(Content)
# Out:
# ['6.1.1.1 PROJECT CHARTER\n\nDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule.\n\n6.1.1.2 PROJECT MANAGEMENT PLAN\nDescribed in Section 4.3.2.1. Project management plan components include but are not limited to:\n\n Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scope\nwill be defined and developed, which will provide information on how the schedule will be developed.\n\n Development approach. Described in Section 4.2.3.1. The product development approach will help define the\nscheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule.\n\n6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n\nThe enterprise environmental factors that can influence the Plan Schedule Management process include but are not\nlimited to:\n\n Organizational culture and structure,\n Team resource availability and skills and phy
# ...

# %%
a = []
for i in Content:
    if i not in a:
        a.append(i)
Content= a
print(Content)
# Out:
# ['6.1.1.1 PROJECT CHARTER\n\nDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule.\n\n6.1.1.2 PROJECT MANAGEMENT PLAN\nDescribed in Section 4.3.2.1. Project management plan components include but are not limited to:\n\n Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scope\nwill be defined and developed, which will provide information on how the schedule will be developed.\n\n Development approach. Described in Section 4.2.3.1. The product development approach will help define the\nscheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule.\n\n6.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n\nThe enterprise environmental factors that can influence the Plan Schedule Management process include but are not\nlimited to:\n\n Organizational culture and structure,\n Team resource availability and skills and phy
# ...

# %%
Content = list(map(lambda x: x.replace('|', 'PIPE'), Content))

# %%
Content = list(map(lambda x: x.replace('6.1.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.1.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.1.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.1.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.2.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.2.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.2.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.2.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.3.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.3.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.3.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.3.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.4.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.4.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('6.4.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('\n', ''), Content))

Content
# Out:
# [' | 1 PROJECT CHARTERDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule. | 2 PROJECT MANAGEMENT PLANDescribed in Section 4.3.2.1. Project management plan components include but are not limited to: Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scopewill be defined and developed, which will provide information on how the schedule will be developed. Development approach. Described in Section 4.2.3.1. The product development approach will help define thescheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule. | 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Schedule Management process include but are notlimited to: Organizational culture and structure, Team resource availability and skills and physical resource availability, Scheduling softwar
# ...

# %%
mystring=""
for x in Content:
    mystring += x
mystring = mystring.replace('\n', ' ').replace('\r', '')
mystring
# Out:
# ' | 1 PROJECT CHARTERDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule. | 2 PROJECT MANAGEMENT PLANDescribed in Section 4.3.2.1. Project management plan components include but are not limited to: Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scopewill be defined and developed, which will provide information on how the schedule will be developed. Development approach. Described in Section 4.2.3.1. The product development approach will help define thescheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule. | 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Schedule Management process include but are notlimited to: Organizational culture and structure, Team resource availability and skills and physical resource availability, Scheduling software
# ...

# %%
one = mystring.split('|');
one
# Out:
# [' ',
#  ' 1 PROJECT CHARTERDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule. ',
#  ' 2 PROJECT MANAGEMENT PLANDescribed in Section 4.3.2.1. Project management plan components include but are not limited to: Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scopewill be defined and developed, which will provide information on how the schedule will be developed. Development approach. Described in Section 4.2.3.1. The product development approach will help define thescheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule. ',
# ...

# %%
import pandas as pd
df13 = pd.DataFrame(one)
df13=df13.rename(columns = {0:'Content'})
df13
# Out:
#                                               Content
# 0
# 1    1 PROJECT CHARTERDescribed in Section 4.1.3.1...
# 2    2 PROJECT MANAGEMENT PLANDescribed in Section...
# 3    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...
# 4    4 ORGANIZATIONAL PROCE AETSThe organizational...
# ..                                                ...
# 71   1. The number and availability of resources, ...
# 72   1. The schedule management describes the freq...
# 73   8). A forecast trend line can be used to pred...
# 74   1. The schedule management plan may be update...
# 75   2. Schedule performance may indicate the need...
#
# [76 rows x 1 columns]

# %%
df19=df13.join(df18)
df19
# Out:
#                                               Content numSousTitre  \
# 0                                                         6.1.1.1
# 1    1 PROJECT CHARTERDescribed in Section 4.1.3.1...     6.1.1.2
# 2    2 PROJECT MANAGEMENT PLANDescribed in Section...     6.1.1.3
# 3    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...     6.1.1.4
# 4    4 ORGANIZATIONAL PROCE AETSThe organizational...     6.1.2.1
# ..                                                ...          ...
# 71   1. The number and availability of resources, ...     6.6.2.3
# 72   1. The schedule management describes the freq...     6.6.2.4
# 73   8). A forecast trend line can be used to pred...     6.6.2.5
# 74   1. The schedule management plan may be update...     6.6.2.6
# 75   2. Schedule performance may indicate the need...     6.6.3.1
#
#                                      SousTitre  \
# 0                    6.1.1.1 PROJECT CHARTER\n
# 1            6.1.1.2 PROJECT MANAGEMENT PLAN\n
# ...

# %%
df19['numSousChapitre'] = df19['numSousTitre'].str[:5]
df19['numChapitre'] = df19['numSousChapitre'].str[:3]
df19['TYPE']= ''
df19
# Out:
#                                               Content numSousTitre  \
# 0                                                         6.1.1.1
# 1    1 PROJECT CHARTERDescribed in Section 4.1.3.1...     6.1.1.2
# 2    2 PROJECT MANAGEMENT PLANDescribed in Section...     6.1.1.3
# 3    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...     6.1.1.4
# 4    4 ORGANIZATIONAL PROCE AETSThe organizational...     6.1.2.1
# ..                                                ...          ...
# 71   1. The number and availability of resources, ...     6.6.2.3
# 72   1. The schedule management describes the freq...     6.6.2.4
# 73   8). A forecast trend line can be used to pred...     6.6.2.5
# 74   1. The schedule management plan may be update...     6.6.2.6
# 75   2. Schedule performance may indicate the need...     6.6.3.1
#
#                                      SousTitre  \
# 0                    6.1.1.1 PROJECT CHARTER\n
# 1            6.1.1.2 PROJECT MANAGEMENT PLAN\n
# ...

# %%
one.pop(0)
# Out:
# ' '

# %%
one
# Out:
# [' 1 PROJECT CHARTERDescribed in Section 4.1.3.1. The project charter defines the summary milestone schedule that will influence theanagement of the project schedule. ',
#  ' 2 PROJECT MANAGEMENT PLANDescribed in Section 4.3.2.1. Project management plan components include but are not limited to: Scope management plan. Described in Section 5.1.3.1. The scope management plan describes how the scopewill be defined and developed, which will provide information on how the schedule will be developed. Development approach. Described in Section 4.2.3.1. The product development approach will help define thescheduling approach, estimating techniques, scheduling tools, and techniques for controlling the schedule. ',
# ...

# %%
NoDesc=[]
Cont= []
DescBy= []
i=0

interraction = []
for item in one:
    if item[5].isupper():
        i= i +1 
        Cont.append(item)
    else:
        DescBy.append(item)
        if(len(NoDesc)>0):
            Cont[-1]+= item    
NoDesc=list(set(one) - set(DescBy))

# %%
df20=df19.reindex(columns = ['numChapitre', 'Chapitre','numSousChapitre', 'SousChapitre','TYPE','numSousTitre','SousTitre','Content'])
df20['Content'] = df20['Content'].shift(periods=-1)

# %%
df20
# Out:
#    numChapitre                                    Chapitre numSousChapitre  \
# 0          6.1                6.1 CONTROL SCHEDULE: INPUTS           6.1.1
# 1          6.1                6.1 PLAN SCHEDULE MANAGEMENT           6.1.1
# 2          6.1              6.1 Plan Schedule Management—T           6.1.1
# 3          6.1  6.2 CONTROL SCHEDULE: TOOLS AND TECHNIQUES           6.1.1
# 4          6.1                       6.2 DEFINE ACTIVITIES           6.1.2
# ..         ...                                         ...             ...
# 71         6.6                                         NaN           6.6.2
# 72         6.6                                         NaN           6.6.2
# 73         6.6                                         NaN           6.6.2
# 74         6.6                                         NaN           6.6.2
# 75         6.6                                         NaN           6.6.3
#
# ...

# %%
df20['REF']=df20['Content'].str.findall(r'Described in Section \d.\d.\d.\d+')
df20['REF']=df20['REF']+df20['Content'].str.findall(r'depicted in Figure \d+')
df20['REF']=df20['REF']+df20['Content'].str.findall(r'Figure \d\d+')
df20.head(50)
# Out:
#    numChapitre                                           Chapitre  \
# 0          6.1                       6.1 CONTROL SCHEDULE: INPUTS
# 1          6.1                       6.1 PLAN SCHEDULE MANAGEMENT
# 2          6.1                     6.1 Plan Schedule Management—T
# 3          6.1         6.2 CONTROL SCHEDULE: TOOLS AND TECHNIQUES
# 4          6.1                              6.2 DEFINE ACTIVITIES
# 5          6.1                            6.2 Define Activities—T
# 6          6.1                      6.3 CONTROL SCHEDULE: OUTPUTS
# 7          6.1                            6.3 SEQUENCE ACTIVITIES
# 8          6.2                          6.3 Sequence Activities—T
# 9          6.2                    6.4 ESTIMATE ACTIVITY DURATIONS
# 10         6.2                  6.4 Estimate Activity Durations—T
# 11         6.2                               6.5 DEVELOP SCHEDULE
# 12         6.2                             6.5 Develop Schedule—T
# ...

# %%
df20['Content'][21]
# Out:
# ' 5 PROJECT MANAGEMENT PLAN UPDATESAny change to the project management plan goes through the organization’s change control process via a changerequest. Components that may require a change request for the project management plan include but are not limited to: Schedule baseline. Described in Section 6.5.3.1. Throughout the project, work packages are progressivelyelaborated into activities. This process may reveal work that was not part of the initial schedule baseline,necessitating a change to delivery dates or other significant schedule milestones that are part of theschedule baseline. Cost baseline. Described in Section 7.3.3.1. Changes to the cost baseline are incorporated in response toapproved changes in schedule activities.186 6.3 SEQUENCE ACTIVITIESSequence Activities is the process of identifying and documenting relationships among the project activities. The keybenefit of this process is that it defines the logical sequence of work to obtain the greatest efficiency given al
# ...

# %%
df20['REF'][21]
# Out:
# ['Described in Section 6.5.3.1',
#  'Described in Section 7.3.3.1',
#  'depicted in Figure 67',
#  'Figure 67',
#  'Figure 68']

# %%
df20=df20.reindex(columns = ['numChapitre', 'Chapitre','numSousChapitre', 'SousChapitre','TYPE','numSousTitre','SousTitre','Content','REF'])

# %%
for i in range (0,76):
    if ((df20.loc[i,['numChapitre']]=='6.1').bool()):
        df20.loc[i,['Chapitre']]='6.1 Plan Schedule Management\n'
    elif ((df20.loc[i,['numChapitre']]=='6.2').bool()):
        df20.loc[i,['Chapitre']]='6.2 Define Activities\n'
    elif ((df20.loc[i,['numChapitre']]=='6.3').bool()):
        df20.loc[i,['Chapitre']]='6.3 Sequence Activities\n'
    elif ((df20.loc[i,['numChapitre']]=='6.4').bool()):
        df20.loc[i,['Chapitre']]='6.4 Estimate Activity Durations\n'
    elif ((df20.loc[i,['numChapitre']]=='6.5').bool()):
        df20.loc[i,['Chapitre']]='6.5 Develop Schedule\n'
    elif ((df20.loc[i,['numChapitre']]=='6.6').bool()):
        df20.loc[i,['Chapitre']]='6.6 Control Schedule\n'
df20
# Out:
#    numChapitre                        Chapitre numSousChapitre  \
# 0          6.1  6.1 Plan Schedule Management\n           6.1.1
# 1          6.1  6.1 Plan Schedule Management\n           6.1.1
# 2          6.1  6.1 Plan Schedule Management\n           6.1.1
# 3          6.1  6.1 Plan Schedule Management\n           6.1.1
# 4          6.1  6.1 Plan Schedule Management\n           6.1.2
# ..         ...                             ...             ...
# 71         6.6          6.6 Control Schedule\n           6.6.2
# 72         6.6          6.6 Control Schedule\n           6.6.2
# 73         6.6          6.6 Control Schedule\n           6.6.2
# 74         6.6          6.6 Control Schedule\n           6.6.2
# 75         6.6          6.6 Control Schedule\n           6.6.3
#
#                                          SousChapitre TYPE numSousTitre  \
# 0            6.1.1 PLAN SCHEDULE MANAGEMENT: INPUTS\n          6.1.1.1
# ...

# %%
for i in range (0,76):
    if ((df20.loc[i,['numSousChapitre']]=='6.1.1').bool()):
        df20.loc[i,['SousChapitre']]='6.1.1 Pan Schedule Management: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.1.2').bool()):
        df20.loc[i,['SousChapitre']]='6.1.2 Plan Schedule Management: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.1.3').bool()):
        df20.loc[i,['SousChapitre']]='6.1.3 Plan Schedule Management: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.2.1').bool()):
        df20.loc[i,['SousChapitre']]='6.2.1 Define Activities: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.2.2').bool()):
        df20.loc[i,['SousChapitre']]='6.2.2 Define Activities: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.2.3').bool()):
        df20.loc[i,['SousChapitre']]='6.2.3 Define Activities: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.3.1').bool()):
        df20.loc[i,['SousChapitre']]='6.3.1 Sequence Activities: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.3.2').bool()):
        df20.loc[i,['SousChapitre']]='6.3.2 Sequence Activities: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.3.3').bool()):
        df20.loc[i,['SousChapitre']]='6.3.3 Sequence Activities: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.4.1').bool()):
        df20.loc[i,['SousChapitre']]='6.4.1 Estimate Activity Durations: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.4.2').bool()):
        df20.loc[i,['SousChapitre']]='6.4.2 Estimate Activity Durations: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.4.3').bool()):
        df20.loc[i,['SousChapitre']]='6.4.3 Estimate Activity Durations: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.5.1').bool()):
        df20.loc[i,['SousChapitre']]='6.5.1 Develop Schedule: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.5.2').bool()):
        df20.loc[i,['SousChapitre']]='6.5.2 Develop Schedule: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.5.3').bool()):
        df20.loc[i,['SousChapitre']]='6.5.3 Develop Schedule: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.6.1').bool()):
        df20.loc[i,['SousChapitre']]='6.6.1 Control Schedule: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.6.2').bool()):
        df20.loc[i,['SousChapitre']]='6.6.2 Control Schedule: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='6.6.3').bool()):
        df20.loc[i,['SousChapitre']]='6.6.3 Control Schedule: Outputs .\n'
df20
# Out:
#    numChapitre                        Chapitre numSousChapitre  \
# 0          6.1  6.1 Plan Schedule Management\n           6.1.1
# 1          6.1  6.1 Plan Schedule Management\n           6.1.1
# 2          6.1  6.1 Plan Schedule Management\n           6.1.1
# 3          6.1  6.1 Plan Schedule Management\n           6.1.1
# 4          6.1  6.1 Plan Schedule Management\n           6.1.2
# ..         ...                             ...             ...
# 71         6.6          6.6 Control Schedule\n           6.6.2
# 72         6.6          6.6 Control Schedule\n           6.6.2
# 73         6.6          6.6 Control Schedule\n           6.6.2
# 74         6.6          6.6 Control Schedule\n           6.6.2
# 75         6.6          6.6 Control Schedule\n           6.6.3
#
#                                          SousChapitre TYPE numSousTitre  \
# 0             6.1.1 Pan Schedule Management: Inputs\n          6.1.1.1
# ...

# %%
for i in range(0,76):
    if ((df20.loc[i,['SousChapitre']].str.contains('INPUTS')).bool()):
        df20.loc[i,['TYPE']]='INPUTS'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Inputs')).bool()):
        df20.loc[i,['TYPE']]='INPUTS'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Tools and Techniques')).bool()):
        df20.loc[i,['TYPE']]='Tools and Techniques'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Outputs')).bool()):
        df20.loc[i,['TYPE']]='Outputs'
df20
# Out:
#    numChapitre                        Chapitre numSousChapitre  \
# 0          6.1  6.1 Plan Schedule Management\n           6.1.1
# 1          6.1  6.1 Plan Schedule Management\n           6.1.1
# 2          6.1  6.1 Plan Schedule Management\n           6.1.1
# 3          6.1  6.1 Plan Schedule Management\n           6.1.1
# 4          6.1  6.1 Plan Schedule Management\n           6.1.2
# ..         ...                             ...             ...
# 71         6.6          6.6 Control Schedule\n           6.6.2
# 72         6.6          6.6 Control Schedule\n           6.6.2
# 73         6.6          6.6 Control Schedule\n           6.6.2
# 74         6.6          6.6 Control Schedule\n           6.6.2
# 75         6.6          6.6 Control Schedule\n           6.6.3
#
#                                          SousChapitre                  TYPE  \
# 0             6.1.1 Pan Schedule Management: Inputs\n                INPUTS
# ...

# %%
df20.drop(df20.tail(1).index,inplace=True)
df20
# Out:
#    numChapitre                        Chapitre numSousChapitre  \
# 0          6.1  6.1 Plan Schedule Management\n           6.1.1
# 1          6.1  6.1 Plan Schedule Management\n           6.1.1
# 2          6.1  6.1 Plan Schedule Management\n           6.1.1
# 3          6.1  6.1 Plan Schedule Management\n           6.1.1
# 4          6.1  6.1 Plan Schedule Management\n           6.1.2
# ..         ...                             ...             ...
# 70         6.6          6.6 Control Schedule\n           6.6.2
# 71         6.6          6.6 Control Schedule\n           6.6.2
# 72         6.6          6.6 Control Schedule\n           6.6.2
# 73         6.6          6.6 Control Schedule\n           6.6.2
# 74         6.6          6.6 Control Schedule\n           6.6.2
#
#                                          SousChapitre                  TYPE  \
# 0             6.1.1 Pan Schedule Management: Inputs\n                INPUTS
# ...

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import span
from spacy import displacy


import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer,SnowballStemmer
from nltk.corpus import wordnet, stopwords
from nltk import pos_tag, RegexpParser

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\MSI\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MSI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn
def lemmatize_text (text):
    lemmatizer = WordNetLemmatizer()
    return lemmatizer.lemmatize(text)
def synonym (text):
    words = text.split()
    words = [lemmatize_text(i) for i in words]
    synonym = []
    for word in words:
        for syn in wn.synsets(word):
            for l in syn.lemmas():
                synonym.append(l.name())
    return set(synonym)

# %%
df20['synonym'] = df20['Content'].apply(lambda x: synonym(x))

# %%
df20
# Out:
#    numChapitre                        Chapitre numSousChapitre  \
# 0          6.1  6.1 Plan Schedule Management\n           6.1.1
# 1          6.1  6.1 Plan Schedule Management\n           6.1.1
# 2          6.1  6.1 Plan Schedule Management\n           6.1.1
# 3          6.1  6.1 Plan Schedule Management\n           6.1.1
# 4          6.1  6.1 Plan Schedule Management\n           6.1.2
# ..         ...                             ...             ...
# 70         6.6          6.6 Control Schedule\n           6.6.2
# 71         6.6          6.6 Control Schedule\n           6.6.2
# 72         6.6          6.6 Control Schedule\n           6.6.2
# 73         6.6          6.6 Control Schedule\n           6.6.2
# 74         6.6          6.6 Control Schedule\n           6.6.2
#
#                                          SousChapitre                  TYPE  \
# 0             6.1.1 Pan Schedule Management: Inputs\n                INPUTS
# ...

# %%
df20.to_csv('ScheduleTEST.csv', sep=' ', encoding='utf-8', header='true')
