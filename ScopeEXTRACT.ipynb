# %%
# Useful libraries
from pdf2image import convert_from_path
from pytesseract import image_to_string
from PIL import Image
import csv 
import re

# %%
def convert_pdf_to_img(pdf_file):

    return convert_from_path(pdf_file)


def convert_image_to_text(file):

    
    text = image_to_string(file)
    return text


def get_text_from_any_pdf(pdf_file):

    images = convert_pdf_to_img(pdf_file)
    final_text = ""
    for pg, img in enumerate(images):
        
        final_text += convert_image_to_text(img)
        #print("Page n°{}".format(pg))
        #print(convert_image_to_text(img))
    
    return final_text

# %%
path_to_pdf = 'Scope.pdf'

# %%
textextract = get_text_from_any_pdf(path_to_pdf)
print(textextract)
# Out:
# PROJECT SCOPE MANAGEMENT
#
# Project Scope Management includes the processes required to ensure that the project includes all the work required,
# and only the work required, to complete the project successfully. Managing the project scope is primarily concerned with
# defining and controlling what is and is not included in the project.
#
# The Project Scope Management processes are:
#
# 5.1 Plan Scope Management—The process of creating a scope management plan that documents how the project
# and product scope will be defined, validated, and controlled.
#
# 5.2 Collect Requirements—The process of determining, documenting, and managing stakeholder needs and
# requirements to meet project objectives.
#
# 5.3 Define Scope—the process of developing a detailed description of the project and product.
#
# 5.4 Create WBS—The process of subdividing project deliverables and project work into smaller, more manageable
# components.
#
# ...

# %%
import re
Figure = re.findall(r"Figure\s[5]-[0-9]{1,2}.\s[A-Z]{1}.*", textextract)
Figure.sort()
Figure
# Out:
# ['Figure 5-1. Project Scope Management Overview',
#  'Figure 5-10. Create WBS: Inputs, Tools & Techniques, and Outputs',
#  'Figure 5-10. Figure 5-11 depicts the data flow diagram of the process.',
#  'Figure 5-11. Create WBS: Data Flow Diagram',
#  'Figure 5-12. Sample WBS Decomposed Down Through Work Packages',
#  'Figure 5-13. Sample WBS Organized by Phase',
#  'Figure 5-14. Sample WBS with Major Deliverables',
#  'Figure 5-15. Figure 5-16 depicts',
#  'Figure 5-15. Validate Scope: Inputs, Tools & Techniques, and Outputs',
#  'Figure 5-16. Validate Scope: Data Flow Diagram',
#  'Figure 5-17. Control Scope: Inputs, Tools & Techniques, and Outputs',
#  'Figure 5-17. Figure 5-18 depicts the data flow diagram of the process.',
#  'Figure 5-18. Control Scope: Data Flow Diagram',
#  'Figure 5-2. Figure 5-3 depicts',
#  'Figure 5-2. Plan Scope Management: Inputs, Tools & Techniques, and Outputs',
#  'Figure 5-3. Plan Scope Management: Data Flow Diagram',
# ...

# %%
import pandas as pd
dict = {'Figure': Figure}
df22 = pd.DataFrame(dict)
df22
# Out:
#                                                Figure
# 0       Figure 5-1. Project Scope Management Overview
# 1   Figure 5-10. Create WBS: Inputs, Tools & Techn...
# 2   Figure 5-10. Figure 5-11 depicts the data flow...
# 3          Figure 5-11. Create WBS: Data Flow Diagram
# 4   Figure 5-12. Sample WBS Decomposed Down Throug...
# 5          Figure 5-13. Sample WBS Organized by Phase
# 6     Figure 5-14. Sample WBS with Major Deliverables
# 7                    Figure 5-15. Figure 5-16 depicts
# 8   Figure 5-15. Validate Scope: Inputs, Tools & T...
# 9      Figure 5-16. Validate Scope: Data Flow Diagram
# 10  Figure 5-17. Control Scope: Inputs, Tools & Te...
# 11  Figure 5-17. Figure 5-18 depicts the data flow...
# 12      Figure 5-18. Control Scope: Data Flow Diagram
# 13                     Figure 5-2. Figure 5-3 depicts
# 14  Figure 5-2. Plan Scope Management: Inputs, Too...
# 15  Figure 5-3. Plan Scope Management: Data Flow D...
# ...

# %%
path_to_pdf = 'ScopeSansFigure.pdf'

# %%
textextract = get_text_from_any_pdf(path_to_pdf)
print(textextract)
# Out:
# PROJECT SCOPE MANAGEMENT
#
# Project Scope Management includes the processes required to ensure that the project includes all the work required,
# and only the work required, to complete the project successfully. Managing the project scope is primarily concerned with
# defining and controlling what is and is not included in the project.
#
# The Project Scope Management processes are:
#
# 5.1 Plan Scope Management—The process of creating a scope management plan that documents how the project
# and product scope will be defined, validated, and controlled.
#
# 5.2 Collect Requirements—The process of determining, documenting, and managing stakeholder needs and
# requirements to meet project objectives.
#
# 5.3 Define Scope—The process of developing a detailed description of the project and product.
#
# 5.4 Create WBS—The process of subdividing project deliverables and project work into smaller, more manageable
# components.
#
# ...

# %%
textextract=textextract.replace("@","")
textextract=textextract.replace("¢","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
#textextract=textextract.replace(".","")
textextract=textextract.replace("©","")
textextract=textextract.replace("*","")
textextract=textextract.replace("-","")
textextract=textextract.replace("Part 1  Guide","")
textextract=textextract.replace("'","")
#textextract=textextract.replace("71","souschapitre1")
#textextract=textextract.replace("72","souschapitre2")
#textextract=textextract.replace("73","souschapitre3")
#textextract=textextract.replace("74","souschapitre4")

textextract = textextract.replace('; 7A', '')
textextract = textextract.replace('eecccccccccsccsccccccoe >', '')
textextract = textextract.replace('\nm', '')
textextract = textextract.replace('SS', '')
textextract = textextract.replace('XR J', '')
textextract = textextract.replace('« ', '')
textextract = textextract.replace('m=>', '')
textextract = textextract.replace('= ', '')
textextract = textextract.replace('wy', '')
textextract = textextract.replace('ececcececencccccccccccececceseeg|', '')
textextract = textextract.replace('| seeerceecccccsccccccscn de Documents', '')
textextract = textextract.replace('=e', '')
textextract = textextract.replace('ez', '')
textextract = textextract.replace('———>', '')
textextract = textextract.replace('\no', '')
with open('ScopeSansFigure.txt', 'w', encoding="utf-8") as fp:
    fp.write(textextract)

# %%
textextract
# Out:
# 'PROJECT SCOPE MANAGEMENT\n\nProject Scope Management includes the processes required to ensure that the project includes all the work required,\nand only the work required, to complete the project successfully. Managing the project scope is primarily concerned with\ndefining and controlling what is and is not included in the project.\n\nThe Project Scope Management processes are:\n\n5.1 Plan Scope Management—The process of creating a scope management plan that documents how the project\nand product scope will be defined, validated, and controlled.\n\n5.2 Collect Requirements—The process of determining, documenting, and managing stakeholder needs and\nrequirements to meet project objectives.\n\n5.3 Define Scope—The process of developing a detailed description of the project and product.\n\n5.4 Create WBS—The process of subdividing project deliverables and project work into smaller, more manageable\ncomponents.\n\n5.5 Validate Scope—The process of formalizing acceptance of the complet
# ...

# %%
SousTitre = re.findall(r"[5].[0-9].[0-9].[0-9].*[A-Z]\n", textextract)
SousTitre.sort()
SousTitre
# Out:
# ['5.1.1.1. PROJECT CHARTER\n',
#  '5.1.1.2 PROJECT MANAGEMENT PLAN\n',
#  '5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '5.1.1.4 ORGANIZATIONAL PROCE AETS\n',
#  '5.1.2.1 EXPERT JUDGMENT\n',
#  '5.1.2.2 DATA ANALYSIS\n',
#  '5.1.2.3 MEETINGS\n',
#  '5.1.3.1 SCOPE MANAGEMENT PLAN\n',
#  '5.1.3.2 REQUIREMENTS MANAGEMENT PLAN\n',
#  '5.2.1.1 PROJECT CHARTER\n',
#  '5.2.1.2 PROJECT MANAGEMENT PLAN\n',
#  '5.2.1.3 PROJECT DOCUMENTS\n',
#  '5.2.1.4 BUSINE DOCUMENTS\n',
#  '5.2.1.5 AGREEMENTS\n',
#  '5.2.1.6 ENTERPRISE ENVIRONMENTAL FACTORS\n',
#  '5.2.1.7 ORGANIZATIONAL PROCE AETS\n',
#  '5.2.2.1 EXPERT JUDGMENT\n',
#  '5.2.2.2 DATA GATHERING\n',
#  '5.2.2.3 DATA ANALYSIS\n',
#  '5.2.2.4 DECISION MAKING\n',
#  '5.2.2.5 DATA REPRESENTATION\n',
#  '5.2.2.6 INTERPERSONAL AND TEAM SKILLS\n',
#  '5.2.2.7 CONTEXT DIAGRAM\n',
#  '5.2.2.8 PROTOTYPES\n',
#  '5.2.3.1 REQUIREMENTS DOCUMENTATION\n',
#  '5.2.3.2 REQUIREMENTS TRACEABILITY MATRIX\n',
#  '5.3.1.1 PROJECT CHARTER\n',
# ...

# %%
import pandas as pd
dict = {'SousTitre': SousTitre}
df = pd.DataFrame(dict)
df
# Out:
#                                      SousTitre
# 0                   5.1.1.1. PROJECT CHARTER\n
# 1            5.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2   5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3          5.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4                    5.1.2.1 EXPERT JUDGMENT\n
# ..                                         ...
# 60                     5.6.2.1 DATA ANALYSIS\n
# 61      5.6.3.1 WORK PERFORMANCE INFORMATION\n
# 62                   5.6.3.2 CHANGE REQUESTS\n
# 63   5.6.3.3 PROJECT MANAGEMENT PLAN UPDATES\n
# 64         5.6.3.4 PROJECT DOCUMENTS UPDATES\n
#
# [65 rows x 1 columns]

# %%
numSousTitre=[]
numSousTitre = re.findall(r"[5].[0-9].[0-9].[0-9] ", textextract)
numSousTitre
# Out:
# ['5.1.1.2 ',
#  '5.1.1.3 ',
#  '5.1.1.4 ',
#  '5.1.2.1 ',
#  '5.1.2.2 ',
#  '5.1.2.3 ',
#  '5.1.3.1 ',
#  '5.1.3.2 ',
#  '5.2.1.1 ',
#  '5.2.1.2 ',
#  '5.2.1.3 ',
#  '5.2.1.4 ',
#  '5.2.1.5 ',
#  '5.2.1.6 ',
#  '5.2.1.7 ',
#  '5.2.2.1 ',
#  '5.2.2.2 ',
#  '5.2.2.3 ',
#  '5.2.2.4 ',
#  '5.2.2.5 ',
#  '5.2.2.6 ',
#  '5.2.2.7 ',
#  '5.2.2.8 ',
#  '5.2.3.1 ',
#  '5.2.3.2 ',
#  '5.3.1.1 ',
#  '5.3.1.2 ',
#  '5.3.1.3 ',
#  '5.3.1.4 ',
#  '5.3.1.5 ',
#  '5.3.2.1 ',
#  '5.3.2.2 ',
#  '5.3.2.3 ',
#  '5.3.2.4 ',
#  '5.3.2.5 ',
#  '5.3.3.2 ',
#  '5.4.1.2 ',
#  '5.4.1.3 ',
#  '5.4.1.4 ',
#  '5.4.2.1 ',
#  '5.4.2.2 ',
#  '5.4.3.1 ',
#  '5.4.3.2 ',
#  '5.5.1.1 ',
#  '5.5.1.2 ',
#  '5.5.1.3 ',
#  '5.5.1.4 ',
#  '5.5.2.1 ',
#  '5.5.2.2 ',
#  '5.5.3.1 ',
#  '5.5.3.2 ',
#  '5.5.3.3 ',
#  '5.5.3.4 ',
#  '5.6.1.1 ',
#  '5.6.1.2 ',
#  '5.6.1.3 ',
#  '5.6.1.4 ',
#  '5.6.2.1 ',
#  '5.6.3.1 ',
#  '5.6.3.2 ',
#  '5.6.3.3 ',
#  '5.6.3.4 ']

# %%
import pandas as pd
dict = {'numSousTitre': numSousTitre} 
df4 = pd.DataFrame(dict)
df4.shape
# Out:
# (62, 1)

# %%
df100=df.join(df22)
df5=df4.join(df100)
df5
# Out:
#    numSousTitre                                   SousTitre  \
# 0      5.1.1.2                   5.1.1.1. PROJECT CHARTER\n
# 1      5.1.1.3            5.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2      5.1.1.4   5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3      5.1.2.1          5.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4      5.1.2.2                    5.1.2.1 EXPERT JUDGMENT\n
# ..          ...                                         ...
# 57     5.6.2.1                  5.6.1.2 PROJECT DOCUMENTS\n
# 58     5.6.3.1              5.6.1.3 WORK PERFORMANCE DATA\n
# 59     5.6.3.2          5.6.1.4 ORGANIZATIONAL PROCE AETS\n
# 60     5.6.3.3                      5.6.2.1 DATA ANALYSIS\n
# 61     5.6.3.4       5.6.3.1 WORK PERFORMANCE INFORMATION\n
#
#                                                Figure
# 0       Figure 5-1. Project Scope Management Overview
# 1   Figure 5-10. Create WBS: Inputs, Tools & Techn...
# 2   Figure 5-10. Figure 5-11 depicts the data flow...
# ...

# %%
Chapitre = re.findall(r"[5].[0-9] .*[A-Z]", textextract)
Chapitre.sort()
Chapitre
# Out:
# ['5.1 PLAN SCOPE MANAGEMENT',
#  '5.1 Plan Scope Management—T',
#  '5.1 VALIDATE SCOPE: INPUTS',
#  '5.2 COLLECT REQUIREMENTS',
#  '5.2 Collect Requirements—T',
#  '5.2 VALIDATE SCOPE: TOOLS AND TECHNIQUES',
#  '5.3 DEFINE SCOPE',
#  '5.3 Define Scope—T',
#  '5.3 VALIDATE SCOPE: OUTPUTS',
#  '5.4 CREATE WBS',
#  '5.4 Create WBS—T',
#  '5.5 VALIDATE SCOPE',
#  '5.5 Validate Scope—T',
#  '5.6 CONTROL SCOPE',
#  '5.6 Control Scope—T']

# %%
dict = {'Chapitre': Chapitre} 
df17 = pd.DataFrame(dict)
df17
# Out:
#                                     Chapitre
# 0                  5.1 PLAN SCOPE MANAGEMENT
# 1                5.1 Plan Scope Management—T
# 2                 5.1 VALIDATE SCOPE: INPUTS
# 3                   5.2 COLLECT REQUIREMENTS
# 4                 5.2 Collect Requirements—T
# 5   5.2 VALIDATE SCOPE: TOOLS AND TECHNIQUES
# 6                           5.3 DEFINE SCOPE
# 7                         5.3 Define Scope—T
# 8                5.3 VALIDATE SCOPE: OUTPUTS
# 9                             5.4 CREATE WBS
# 10                          5.4 Create WBS—T
# 11                        5.5 VALIDATE SCOPE
# 12                      5.5 Validate Scope—T
# 13                         5.6 CONTROL SCOPE
# 14                       5.6 Control Scope—T

# %%
numChapitre = re.findall(r"[5].[0-9] ",textextract)
numChapitre.sort()
numChapitre
# Out:
# ['5.1 ',
#  '5.1 ',
#  '5.1 ',
#  '5.2 ',
#  '5.2 ',
#  '5.2 ',
#  '5.3 ',
#  '5.3 ',
#  '5.3 ',
#  '5.4 ',
#  '5.4 ',
#  '5.5 ',
#  '5.5 ',
#  '5.6 ',
#  '5.6 ',
#  '511 ',
#  '516 ',
#  '518 ']

# %%
dict = {'numChapitre': numChapitre} 
df16 = pd.DataFrame(dict)
df16
# Out:
#    numChapitre
# 0         5.1
# 1         5.1
# 2         5.1
# 3         5.2
# 4         5.2
# 5         5.2
# 6         5.3
# 7         5.3
# 8         5.3
# 9         5.4
# 10        5.4
# 11        5.5
# 12        5.5
# 13        5.6
# 14        5.6
# 15        511
# 16        516
# 17        518

# %%
df15= df16.join(df17)
df15
# Out:
#    numChapitre                                  Chapitre
# 0         5.1                  5.1 PLAN SCOPE MANAGEMENT
# 1         5.1                5.1 Plan Scope Management—T
# 2         5.1                 5.1 VALIDATE SCOPE: INPUTS
# 3         5.2                   5.2 COLLECT REQUIREMENTS
# 4         5.2                 5.2 Collect Requirements—T
# 5         5.2   5.2 VALIDATE SCOPE: TOOLS AND TECHNIQUES
# 6         5.3                           5.3 DEFINE SCOPE
# 7         5.3                         5.3 Define Scope—T
# 8         5.3                5.3 VALIDATE SCOPE: OUTPUTS
# 9         5.4                             5.4 CREATE WBS
# 10        5.4                           5.4 Create WBS—T
# 11        5.5                         5.5 VALIDATE SCOPE
# 12        5.5                       5.5 Validate Scope—T
# 13        5.6                          5.6 CONTROL SCOPE
# 14        5.6                        5.6 Control Scope—T
# ...

# %%
SousChapitre = re.findall(r"[5].[0-9].[0-9] .*[A-Z]\n", textextract)
SousChapitre.sort()
SousChapitre
# Out:
# ['5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n',
#  '5.1.1 PROJECT MANAGEMENT PLAN\n',
#  '5.1.2 PLAN SCOPE MANAGEMENT: TOOLS AND TECHNIQUES\n',
#  '5.1.2 PROJECT DOCUMENTS\n',
#  '5.1.3 PLAN SCOPE MANAGEMENT: OUTPUTS\n',
#  '5.1.3 VERIFIED DELIVERABLES\n',
#  '5.1.4 WORK PERFORMANCE DATA\n',
#  '5.2.1 COLLECT REQUIREMENTS: INPUTS\n',
#  '5.2.1 INSPECTION\n',
#  '5.2.2 COLLECT REQUIREMENTS: TOOLS AND TECHNIQUES\n',
#  '5.2.2 DECISION MAKING\n',
#  '5.2.3 COLLECT REQUIREMENTS: OUTPUTS\n',
#  '5.3.1 ACCEPTED DELIVERABLES\n',
#  '5.3.1 DEFINE SCOPE: INPUTS\n',
#  '5.3.2 DEFINE SCOPE: TOOLS AND TECHNIQUES\n',
#  '5.3.2 WORK PERFORMANCE INFORMATION\n',
#  '5.3.3 CHANGE REQUESTS\n',
#  '5.3.3 DEFINE SCOPE: OUTPUTS\n',
#  '5.3.4 PROJECT DOCUMENTS UPDATES\n',
#  '5.4.1 CREATE WBS: INPUTS\n',
#  '5.4.2 CREATE WBS: TOOLS AND TECHNIQUES\n',
#  '5.4.3 CREATE WBS: OUTPUTS\n',
#  '5.5.1 VALIDATE SCOPE: INPUTS\n',
#  '5.5.2 VALIDATE SCOPE: TOOLS AND TECHNIQUES\n',
#  '5.5.3 VALIDATE SCOPE: OUTPUTS\n',
# ...

# %%
import pandas as pd
dict = {'SousChapitre': SousChapitre} 
df1 = pd.DataFrame(dict)
df1
# Out:
#                                          SousChapitre
# 0               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n
# 1                     5.1.1 PROJECT MANAGEMENT PLAN\n
# 2   5.1.2 PLAN SCOPE MANAGEMENT: TOOLS AND TECHNIQ...
# 3                           5.1.2 PROJECT DOCUMENTS\n
# 4              5.1.3 PLAN SCOPE MANAGEMENT: OUTPUTS\n
# 5                       5.1.3 VERIFIED DELIVERABLES\n
# 6                       5.1.4 WORK PERFORMANCE DATA\n
# 7                5.2.1 COLLECT REQUIREMENTS: INPUTS\n
# 8                                  5.2.1 INSPECTION\n
# 9   5.2.2 COLLECT REQUIREMENTS: TOOLS AND TECHNIQU...
# 10                            5.2.2 DECISION MAKING\n
# 11              5.2.3 COLLECT REQUIREMENTS: OUTPUTS\n
# 12                      5.3.1 ACCEPTED DELIVERABLES\n
# 13                       5.3.1 DEFINE SCOPE: INPUTS\n
# 14         5.3.2 DEFINE SCOPE: TOOLS AND TECHNIQUES\n
# 15               5.3.2 WORK PERFORMANCE INFORMATION\n
# ...

# %%
numSousChapitre = re.findall(r"[5].[0-9].[0-9] ", textextract)
numSousChapitre.sort()
numSousChapitre
# Out:
# ['5.1.1 ',
#  '5.1.1 ',
#  '5.1.2 ',
#  '5.1.2 ',
#  '5.1.3 ',
#  '5.1.3 ',
#  '5.1.4 ',
#  '5.2.1 ',
#  '5.2.1 ',
#  '5.2.2 ',
#  '5.2.2 ',
#  '5.2.3 ',
#  '5.3.1 ',
#  '5.3.1 ',
#  '5.3.2 ',
#  '5.3.2 ',
#  '5.3.3 ',
#  '5.3.3 ',
#  '5.3.4 ',
#  '5.4.1 ',
#  '5.4.2 ',
#  '5.4.3 ',
#  '5.5.1 ',
#  '5.5.2 ',
#  '5.5.3 ',
#  '5.6.1 ',
#  '5.6.2 ',
#  '5.6.3 ']

# %%
dict = {'numSousChapitre': numSousChapitre} 
df11 = pd.DataFrame(dict)
df11
# Out:
#    numSousChapitre
# 0           5.1.1
# 1           5.1.1
# 2           5.1.2
# 3           5.1.2
# 4           5.1.3
# 5           5.1.3
# 6           5.1.4
# 7           5.2.1
# 8           5.2.1
# 9           5.2.2
# 10          5.2.2
# 11          5.2.3
# 12          5.3.1
# 13          5.3.1
# 14          5.3.2
# 15          5.3.2
# 16          5.3.3
# 17          5.3.3
# 18          5.3.4
# 19          5.4.1
# 20          5.4.2
# 21          5.4.3
# 22          5.5.1
# 23          5.5.2
# 24          5.5.3
# 25          5.6.1
# 26          5.6.2
# 27          5.6.3

# %%
df23=df11.join(df1)
df23
# Out:
#    numSousChapitre                                       SousChapitre
# 0           5.1.1               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n
# 1           5.1.1                     5.1.1 PROJECT MANAGEMENT PLAN\n
# 2           5.1.2   5.1.2 PLAN SCOPE MANAGEMENT: TOOLS AND TECHNIQ...
# 3           5.1.2                           5.1.2 PROJECT DOCUMENTS\n
# 4           5.1.3              5.1.3 PLAN SCOPE MANAGEMENT: OUTPUTS\n
# 5           5.1.3                       5.1.3 VERIFIED DELIVERABLES\n
# 6           5.1.4                       5.1.4 WORK PERFORMANCE DATA\n
# 7           5.2.1                5.2.1 COLLECT REQUIREMENTS: INPUTS\n
# 8           5.2.1                                  5.2.1 INSPECTION\n
# 9           5.2.2   5.2.2 COLLECT REQUIREMENTS: TOOLS AND TECHNIQU...
# 10          5.2.2                             5.2.2 DECISION MAKING\n
# 11          5.2.3               5.2.3 COLLECT REQUIREMENTS: OUTPUTS\n
# ...

# %%
df3=df23.join(df15)
df3
# Out:
#    numSousChapitre                                       SousChapitre  \
# 0           5.1.1               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n
# 1           5.1.1                     5.1.1 PROJECT MANAGEMENT PLAN\n
# 2           5.1.2   5.1.2 PLAN SCOPE MANAGEMENT: TOOLS AND TECHNIQ...
# 3           5.1.2                           5.1.2 PROJECT DOCUMENTS\n
# 4           5.1.3              5.1.3 PLAN SCOPE MANAGEMENT: OUTPUTS\n
# 5           5.1.3                       5.1.3 VERIFIED DELIVERABLES\n
# 6           5.1.4                       5.1.4 WORK PERFORMANCE DATA\n
# 7           5.2.1                5.2.1 COLLECT REQUIREMENTS: INPUTS\n
# 8           5.2.1                                  5.2.1 INSPECTION\n
# 9           5.2.2   5.2.2 COLLECT REQUIREMENTS: TOOLS AND TECHNIQU...
# 10          5.2.2                             5.2.2 DECISION MAKING\n
# 11          5.2.3               5.2.3 COLLECT REQUIREMENTS: OUTPUTS\n
# ...

# %%
df18=df5.join(df3)
df18
# Out:
#    numSousTitre                                   SousTitre  \
# 0      5.1.1.2                   5.1.1.1. PROJECT CHARTER\n
# 1      5.1.1.3            5.1.1.2 PROJECT MANAGEMENT PLAN\n
# 2      5.1.1.4   5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n
# 3      5.1.2.1          5.1.1.4 ORGANIZATIONAL PROCE AETS\n
# 4      5.1.2.2                    5.1.2.1 EXPERT JUDGMENT\n
# ..          ...                                         ...
# 57     5.6.2.1                  5.6.1.2 PROJECT DOCUMENTS\n
# 58     5.6.3.1              5.6.1.3 WORK PERFORMANCE DATA\n
# 59     5.6.3.2          5.6.1.4 ORGANIZATIONAL PROCE AETS\n
# 60     5.6.3.3                      5.6.2.1 DATA ANALYSIS\n
# 61     5.6.3.4       5.6.3.1 WORK PERFORMANCE INFORMATION\n
#
#                                                Figure numSousChapitre  \
# 0       Figure 5-1. Project Scope Management Overview          5.1.1
# 1   Figure 5-10. Create WBS: Inputs, Tools & Techn...          5.1.1
# ...

# %%
Content = re.findall(r'[0-9].[0-9].[0-9].[0-9][^\S\n]+[A-Z]+[\S\n+](?:[^\S\n]+[A-Z]+)*(?:\n(?!7\.\[0-9].[0-9].[0-9].[0-9]).*)+', textextract)
print(Content)
# Out:
# ['5.1.1.2 PROJECT MANAGEMENT PLAN\nDescribed in Section 4.2.3.1. Project management plan components include but are not limited to:\n\n Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards are\nimplemented on the project.\n\n Project life cycle description. The project life cycle determines the series of phases that a project passes\nthrough from its inception to the end of the project.\n\n Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or a\nhybrid development approach will be used.\n\n5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n\nThe enterprise environmental factors that can influence the Plan Scope Management process include but are not\nlimited to:\n\n Organizations culture,\n Infrastructure,\n Personnel administration, and\n\n Marketplace conditions.\n\n5.1.1.4 ORGANIZATIONAL PROCE AETS
# ...

# %%
a = []
for i in Content:
    if i not in a:
        a.append(i)
Content= a
print(Content)
# Out:
# ['5.1.1.2 PROJECT MANAGEMENT PLAN\nDescribed in Section 4.2.3.1. Project management plan components include but are not limited to:\n\n Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards are\nimplemented on the project.\n\n Project life cycle description. The project life cycle determines the series of phases that a project passes\nthrough from its inception to the end of the project.\n\n Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or a\nhybrid development approach will be used.\n\n5.1.1.3 ENTERPRISE ENVIRONMENTAL FACTORS\n\nThe enterprise environmental factors that can influence the Plan Scope Management process include but are not\nlimited to:\n\n Organizations culture,\n Infrastructure,\n Personnel administration, and\n\n Marketplace conditions.\n\n5.1.1.4 ORGANIZATIONAL PROCE AETS
# ...

# %%
Content = list(map(lambda x: x.replace('|', 'PIPE'), Content))

# %%
Content = list(map(lambda x: x.replace('5.1.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.1.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.1.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.1.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.2.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.2.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.2.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.2.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.3.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.3.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.3.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.3.4.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.4.1.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.4.2.', ' | '), Content))
Content = list(map(lambda x: x.replace('5.4.3.', ' | '), Content))
Content = list(map(lambda x: x.replace('\n', ''), Content))

Content
# Out:
# [' | 2 PROJECT MANAGEMENT PLANDescribed in Section 4.2.3.1. Project management plan components include but are not limited to: Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards areimplemented on the project. Project life cycle description. The project life cycle determines the series of phases that a project passesthrough from its inception to the end of the project. Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or ahybrid development approach will be used. | 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Scope Management process include but are notlimited to: Organizations culture, Infrastructure, Personnel administration, and Marketplace conditions. | 4 ORGANIZATIONAL PROCE AETSThe organizational process assets that can influence th
# ...

# %%
mystring=""
for x in Content:
    mystring += x
mystring = mystring.replace('\n', ' ').replace('\r', '')
mystring
# Out:
# ' | 2 PROJECT MANAGEMENT PLANDescribed in Section 4.2.3.1. Project management plan components include but are not limited to: Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards areimplemented on the project. Project life cycle description. The project life cycle determines the series of phases that a project passesthrough from its inception to the end of the project. Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or ahybrid development approach will be used. | 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Scope Management process include but are notlimited to: Organizations culture, Infrastructure, Personnel administration, and Marketplace conditions. | 4 ORGANIZATIONAL PROCE AETSThe organizational process assets that can influence the
# ...

# %%
one = mystring.split('|');
one
# Out:
# [' ',
#  ' 2 PROJECT MANAGEMENT PLANDescribed in Section 4.2.3.1. Project management plan components include but are not limited to: Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards areimplemented on the project. Project life cycle description. The project life cycle determines the series of phases that a project passesthrough from its inception to the end of the project. Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or ahybrid development approach will be used. ',
#  ' 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Scope Management process include but are notlimited to: Organizations culture, Infrastructure, Personnel administration, and Marketplace conditions. ',
# ...

# %%
import pandas as pd
df13 = pd.DataFrame(one)
df13=df13.rename(columns = {0:'Content'})
df13
# Out:
#                                               Content
# 0
# 1    2 PROJECT MANAGEMENT PLANDescribed in Section...
# 2    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...
# 3    4 ORGANIZATIONAL PROCE AETSThe organizational...
# 4    1 EXPERT JUDGMENTDescribed in Section 4.1.2.1...
# ..                                                ...
# 75   1. The scope management plan may be updated t...
# 76   1. Changes to the scope baseline are incorpor...
# 77    Changes to the schedule baseline are incorpo...
# 78   1. Requirements documentation may be updatedw...
# 79   2. The requirements traceability matrix may b...
#
# [80 rows x 1 columns]

# %%
df19=df13.join(df18)
df19
# Out:
#                                               Content numSousTitre  \
# 0                                                         5.1.1.2
# 1    2 PROJECT MANAGEMENT PLANDescribed in Section...     5.1.1.3
# 2    3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterpr...     5.1.1.4
# 3    4 ORGANIZATIONAL PROCE AETSThe organizational...     5.1.2.1
# 4    1 EXPERT JUDGMENTDescribed in Section 4.1.2.1...     5.1.2.2
# ..                                                ...          ...
# 75   1. The scope management plan may be updated t...          NaN
# 76   1. Changes to the scope baseline are incorpor...          NaN
# 77    Changes to the schedule baseline are incorpo...          NaN
# 78   1. Requirements documentation may be updatedw...          NaN
# 79   2. The requirements traceability matrix may b...          NaN
#
#                                      SousTitre  \
# 0                   5.1.1.1. PROJECT CHARTER\n
# 1            5.1.1.2 PROJECT MANAGEMENT PLAN\n
# ...

# %%
df19['numSousChapitre'] = df19['numSousTitre'].str[:5]
df19['numChapitre'] = df19['numSousChapitre'].str[:3]

# %%
one.pop(0)
# Out:
# ' '

# %%
one
# Out:
# [' 2 PROJECT MANAGEMENT PLANDescribed in Section 4.2.3.1. Project management plan components include but are not limited to: Quality management plan. Described in Section 8.1.3.1. The way the project and product scope will beanaged can be influenced by how the organization’s quality policy, methodologies, and standards areimplemented on the project. Project life cycle description. The project life cycle determines the series of phases that a project passesthrough from its inception to the end of the project. Development approach. The development approach defines whether waterfall, iterative, adaptive, agile, or ahybrid development approach will be used. ',
#  ' 3 ENTERPRISE ENVIRONMENTAL FACTORSThe enterprise environmental factors that can influence the Plan Scope Management process include but are notlimited to: Organizations culture, Infrastructure, Personnel administration, and Marketplace conditions. ',
# ...

# %%
NoDesc=[]
Cont= []
DescBy= []
i=0

interraction = []
for item in one:
    if item[5].isupper():
        i= i +1 
        Cont.append(item)
    else:
        DescBy.append(item)
        if(len(NoDesc)>0):
            Cont[-1]+= item    
NoDesc=list(set(one) - set(DescBy))

# %%
df20=df19.reindex(columns = ['numChapitre', 'Chapitre','numSousChapitre', 'SousChapitre','TYPE','numSousTitre','SousTitre','Content'])
df20['Content'] = df20['Content'].shift(periods=-1)

# %%
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1    5.1 PLAN SCOPE MANAGEMENT           5.1.1
# 1          5.1  5.1 Plan Scope Management—T           5.1.1
# 2          5.1   5.1 VALIDATE SCOPE: INPUTS           5.1.1
# 3          5.1     5.2 COLLECT REQUIREMENTS           5.1.2
# 4          5.1   5.2 Collect Requirements—T           5.1.2
# ..         ...                          ...             ...
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
# 79         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n   NaN     5.1.1.2
# 1                     5.1.1 PROJECT MANAGEMENT PLAN\n   NaN     5.1.1.3
# ...

# %%
df20['REF']=df20['Content'].str.findall(r'Described in Section \d.\d.\d.\d+')
df20['REF']=df20['REF']+df20['Content'].str.findall(r'depicted in Figure \d+')
df20['REF']=df20['REF']+df20['Content'].str.findall(r'Figure \d\d+')
df20.head(50)
# Out:
#    numChapitre                                  Chapitre numSousChapitre  \
# 0          5.1                 5.1 PLAN SCOPE MANAGEMENT           5.1.1
# 1          5.1               5.1 Plan Scope Management—T           5.1.1
# 2          5.1                5.1 VALIDATE SCOPE: INPUTS           5.1.1
# 3          5.1                  5.2 COLLECT REQUIREMENTS           5.1.2
# 4          5.1                5.2 Collect Requirements—T           5.1.2
# 5          5.1  5.2 VALIDATE SCOPE: TOOLS AND TECHNIQUES           5.1.2
# 6          5.1                          5.3 DEFINE SCOPE           5.1.3
# 7          5.1                        5.3 Define Scope—T           5.1.3
# 8          5.2               5.3 VALIDATE SCOPE: OUTPUTS           5.2.1
# 9          5.2                            5.4 CREATE WBS           5.2.1
# 10         5.2                          5.4 Create WBS—T           5.2.1
# 11         5.2                        5.5 VALIDATE SCOPE           5.2.1
# ...

# %%
df20=df20.reindex(columns = ['numChapitre', 'Chapitre','numSousChapitre', 'SousChapitre','TYPE','numSousTitre','SousTitre','Content','REF'])
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1    5.1 PLAN SCOPE MANAGEMENT           5.1.1
# 1          5.1  5.1 Plan Scope Management—T           5.1.1
# 2          5.1   5.1 VALIDATE SCOPE: INPUTS           5.1.1
# 3          5.1     5.2 COLLECT REQUIREMENTS           5.1.2
# 4          5.1   5.2 Collect Requirements—T           5.1.2
# ..         ...                          ...             ...
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
# 79         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n   NaN     5.1.1.2
# 1                     5.1.1 PROJECT MANAGEMENT PLAN\n   NaN     5.1.1.3
# ...

# %%
for i in range (0,len(df20['numChapitre'])):
    if ((df20.loc[i,['numChapitre']]=='5.1').bool()):
        df20.loc[i,['Chapitre']]='5.1 Plan Scope Management\n'
    elif ((df20.loc[i,['numChapitre']]=='5.2').bool()):
        df20.loc[i,['Chapitre']]='5.2 Collect Requirements \n'
    elif ((df20.loc[i,['numChapitre']]=='5.3').bool()):
        df20.loc[i,['Chapitre']]='5.3 Define Scope \n'
    elif ((df20.loc[i,['numChapitre']]=='5.4').bool()):
        df20.loc[i,['Chapitre']]='5.4 Create WBS\n'
    elif ((df20.loc[i,['numChapitre']]=='5.5').bool()):
        df20.loc[i,['Chapitre']]='5.5 Validate Scope \n'
    elif ((df20.loc[i,['numChapitre']]=='5.6').bool()):
        df20.loc[i,['Chapitre']]='5.6 Control Scope\n'

# %%
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
# 79         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0               5.1.1 PLAN SCOPE MANAGEMENT: INPUTS\n   NaN     5.1.1.2
# 1                     5.1.1 PROJECT MANAGEMENT PLAN\n   NaN     5.1.1.3
# ...

# %%
for i in range (0,len(df20['numSousChapitre'])):
    if ((df20.loc[i,['numSousChapitre']]=='5.1.1').bool()):
        df20.loc[i,['SousChapitre']]='5.1.1 Plan Scope Management: Inputs \n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.1.2').bool()):
        df20.loc[i,['SousChapitre']]='5.1.2 Plan Scope Management: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.1.3').bool()):
        df20.loc[i,['SousChapitre']]='5.1.3 Plan Scope Management: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.2.1').bool()):
        df20.loc[i,['SousChapitre']]='5.2.1 Collect Requirements: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.2.2').bool()):
        df20.loc[i,['SousChapitre']]='5.2.2 Collect Requirements: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.2.3').bool()):
        df20.loc[i,['SousChapitre']]='5.2.3 Collect Requirements: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.3.1').bool()):
        df20.loc[i,['SousChapitre']]='5.3.1 Define Scope: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.3.2').bool()):
        df20.loc[i,['SousChapitre']]='5.3.2 Define Scope: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.3.3').bool()):
        df20.loc[i,['SousChapitre']]='5.3.3 Define Scope: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.4.1').bool()):
        df20.loc[i,['SousChapitre']]='5.4.1 Create WBS: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.4.2').bool()):
        df20.loc[i,['SousChapitre']]='5.4.2 Create WBS: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.4.3').bool()):
        df20.loc[i,['SousChapitre']]='5.4.3 Create WBS: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.5.1').bool()):
        df20.loc[i,['SousChapitre']]='5.5.1 Validate Scope: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.5.2').bool()):
        df20.loc[i,['SousChapitre']]='5.5.2 Validate Scope: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.5.3').bool()):
        df20.loc[i,['SousChapitre']]='5.5.3 Validate Scope: Outputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.6.1').bool()):
        df20.loc[i,['SousChapitre']]='5.6.1 Control Scope: Inputs\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.6.2').bool()):
        df20.loc[i,['SousChapitre']]='5.6.2 Control Scope: Tools and Techniques\n'
    elif ((df20.loc[i,['numSousChapitre']]=='5.6.3').bool()):
        df20.loc[i,['SousChapitre']]='5.6.3 Control Scope: Outputs\n'

# %%
df20.head(64)
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 59         5.6          5.6 Control Scope\n           5.6.3
# 60         5.6          5.6 Control Scope\n           5.6.3
# 61         5.6          5.6 Control Scope\n           5.6.3
# 62         NaN                          NaN             NaN
# 63         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.2
# 1              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.3
# ...

# %%
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
# 79         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.2
# 1              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.3
# ...

# %%
df20.drop(df20.tail(1).index,inplace=True)
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 74         NaN                          NaN             NaN
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
#
#                                          SousChapitre  TYPE numSousTitre  \
# 0              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.2
# 1              5.1.1 Plan Scope Management: Inputs \n   NaN     5.1.1.3
# ...

# %%
for i in range(0,61):
    if ((df20.loc[i,['SousChapitre']].str.contains('INPUTS')).bool()):
        df20.loc[i,['TYPE']]='INPUTS'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Inputs')).bool()):
        df20.loc[i,['TYPE']]='INPUTS'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Tools and Techniques')).bool()):
        df20.loc[i,['TYPE']]='Tools and Techniques'
    elif ((df20.loc[i,['SousChapitre']].str.contains('Outputs')).bool()):
        df20.loc[i,['TYPE']]='Outputs'
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 74         NaN                          NaN             NaN
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
#
#                                          SousChapitre                  TYPE  \
# 0              5.1.1 Plan Scope Management: Inputs \n                INPUTS
# 1              5.1.1 Plan Scope Management: Inputs \n                INPUTS
# ...

# %%
import spacy
from spacy.matcher import Matcher
from spacy.tokens import span
from spacy import displacy


import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import WordNetLemmatizer,SnowballStemmer
from nltk.corpus import wordnet, stopwords
from nltk import pos_tag, RegexpParser

# %%
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\MSI\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\MSI\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn
def lemmatize_text (text):
    lemmatizer = WordNetLemmatizer()
    return lemmatizer.lemmatize(text)
def synonym (text):
    words = text.split()
    words = [lemmatize_text(i) for i in words]
    synonym = []
    for word in words:
        for syn in wn.synsets(word):
            for l in syn.lemmas():
                synonym.append(l.name())
    return set(synonym)

# %%
df20['synonym'] = df20['Content'].apply(lambda x: synonym(x))

# %%
df20
# Out:
#    numChapitre                     Chapitre numSousChapitre  \
# 0          5.1  5.1 Plan Scope Management\n           5.1.1
# 1          5.1  5.1 Plan Scope Management\n           5.1.1
# 2          5.1  5.1 Plan Scope Management\n           5.1.1
# 3          5.1  5.1 Plan Scope Management\n           5.1.2
# 4          5.1  5.1 Plan Scope Management\n           5.1.2
# ..         ...                          ...             ...
# 74         NaN                          NaN             NaN
# 75         NaN                          NaN             NaN
# 76         NaN                          NaN             NaN
# 77         NaN                          NaN             NaN
# 78         NaN                          NaN             NaN
#
#                                          SousChapitre                  TYPE  \
# 0              5.1.1 Plan Scope Management: Inputs \n                INPUTS
# 1              5.1.1 Plan Scope Management: Inputs \n                INPUTS
# ...

# %%
df20.to_csv('ScopeTEST.csv', sep=' ', encoding='utf-8', header='true')
